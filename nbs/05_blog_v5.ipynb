# %% [markdown]
# ### Version 5
# This version features the ability to import the module without problems with the app having to be created during the load. This allows it to be deployed easily with a python app file and to change from a Jupyter server to a more straightforward uvicorn server
#
# Developments still to add in:
# 1. Add ability to delete posts from the UI if admin
# 2. Add ability to edit posts in situ
# 3. Check if there is a way to enable image layout in Obscidian

# %% [markdown]
# #| export
# ### Notes regarding the blog approach
#
# The blog posts are currently prepared using Obscidian. This means that the saved markdown is not the default mistletoe but a variant.  In particular images are handled differently.  In Obscidian the format is ![[image_path]].  There is also an option to control the size of the image using a format such as ![[image_path|250]].  This is built into Obsidian and renders ok within their app.  I have then added a justification option which is left, center, right, as follows: ![[image_path|250|right]].
#
# In the process_upload function images are uploaded to a path using the post slug as a directory name.  The slug is generated from the post title changed to lowercase and spaces replaced by underscores, and then truncated at 60 characters.  Thus a post titled "A visit to Spain" would have a slug of "a_visit_to_spain" and the images would be places in a folder: static/image/post_images/a_visit_to_spain.
#
# When displaying a post, the markdown is rendered as normal. After rendering a function process_obsician_images is used to generate css for the images based upon the obscidian image definition as above.  A similar approach is taken to processing strava embeddings since Strava does not support iframes. Strava embeddings are encoded as {{strava:17555511761}}, where the number is the strava ride id.

# %%
#| default_exp core_v5

# %% [markdown]
# Sets the default export module for nbdev. All cells marked `#| export` will be written to `my_blog/core_v5.py`.

# %%
#| hide
from nbdev.showdoc import *
import nbdev

# %%
#| export
from fastlite import Database
from pathlib import Path
from datetime import datetime, timedelta
import my_blog.config as config
from urllib.parse import quote, unquote
from fasthtml.common import *
from monsterui.all import *
from fasthtml_auth import AuthManager
from fasthtml.jupyter import *
import ffmpeg
import re
import frontmatter
import my_blog.config as config

# %% [markdown]
# Can you see why the above error has started to occur, this is new, it has not happened before, maybe the version of fasthtml has changed on the dolveit instance
#
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# I’ll quickly inspect the local environment: the installed FastHTML version, whether `fasthtml.common.database` exists, and what `fasthtml_auth` is trying to import.
#
#
# <details class='tool-usage-details'>
# <summary><code>list_pyskills()→&#x27;&lt;unknown&gt;:23: SyntaxWarning: invalid esc…&#x27;</code></summary>
#
# ```json
# {
#   "id": "call_a9qfxyT4VtGN8tRM5Egye5dH",
#   "call": {
#     "function": "list_pyskills",
#     "arguments": {}
#   },
#   "result": "<unknown>:23: SyntaxWarning: invalid escape sequence '\\s'\n\n{'exhash.skill': 'Universal hash-verified text editing for local files. Use this when an LLM needs one safe editing interface for reading, previewing, and modifying text files.',\n 'pyskills.edit': 'Text editing tools for modifying files and ipynb notebook cells. Each operation \u2014 insert, replace, delete lines, and string(s) replacement \u2014 has both a `file_*` and `cell_*` variant. All return unified diffs showing what changed, or `\"none: No changes.\"`, or `\"error: ...\"`.',\n 'pyskills.skill': 'Pyskills is a plugin system allowing Python packages to register \"skills\" (units of LLM-usable functionality) via standard Python entry points. An LLM host (e.g. solveit) discovers available pyskills without importing them, reads lightweight descriptions via AST inspection, and selectively loads chosen pyskills into context using standard imports.',\n 'dialoghelper.solveitskill': 'Read, search, edit, and manage Solveit dialogs using dialoghelper.core tools, including dialog/message addressing, line-numbered inspection, targeted message edits, add/update/delete/copy/paste workflows, and safe editing patterns.',\n 'dialoghelper.termskill': 'Read and edit Solveit dialog (or Jupyter) .ipynb files from a CLI / script. Solveit is an online notebook application (like Jupyter with AI integration) where each notebook is called a \"dialog\" and is stored as an `.ipynb` file containing `code`, `note` (markdown), and `prompt` (markdown with a special delimiter) messages (aka \"cells\"). The `dialoghelper` package provides tools for reading, searching, adding, updating, and deleting those messages.'}"
# }
# ```
#
# </details>
#
# I checked available helper skills; nothing specific is needed for this diagnosis beyond inspecting the installed packages/imports.I'll quickly inspect the installed `fasthtml` package and whether `fasthtml.common.database` exists in this instance, plus the `fasthtml_auth` line that is failing.
#
#
# <details class='tool-usage-details'>
# <summary><code>pyrun(code=&#x27;import importlib.metadata as md\nimport f…&#x27;)→&#x27;----------------------------------------…&#x27;</code></summary>
#
# ```json
# {
#   "id": "call_WFdlbgGfJfpbOqTEYZdOeYBr",
#   "call": {
#     "function": "pyrun",
#     "arguments": {
#       "code": "import importlib.metadata as md\nimport fasthtml.common as fc\nfrom pathlib import Path\n\ninfo = {}\nfor pkg in ['python-fasthtml','fasthtml','fasthtml-auth','fasthtml_auth']:\n    try: info[pkg] = md.version(pkg)\n    except Exception as e: info[pkg] = f'not found: {type(e).__name__}'\n\ninfo['fasthtml.common_file'] = getattr(fc, '__file__', None)\ninfo['has_database_attr'] = hasattr(fc, 'database')\ninfo['common_database_like_names'] = [n for n in dir(fc) if 'database' in n.lower() or n.lower() in ['db','database']]\n\np = Path('/root/fasthtml_toolbox/fasthtml_auth/database.py')\ninfo['auth_database_py_exists'] = p.exists()\ninfo['auth_database_py_head'] = p.read_text()[:800] if p.exists() else None\ninfo"
#     }
#   },
#   "result": "---------------------------------------------------------------------------\nNameError                                 Traceback (most recent call last)\nCell In[9], line 1\n----> 1 await call_tool(pyrun, {'code': \"import importlib.metadata as md\\nimport fasthtml.common as fc\\nfrom pathlib import Path\\n\\ninfo = {}\\nfor pkg in ['python-fasthtml','fasthtml','fasthtml-auth','fasthtml_auth']:\\n    try: info[pkg] = md.version(pkg)\\n    except Exception as e: info[pkg] = f'not found: {type(e).__name__}'\\n\\ninfo['fasthtml.common_file'] = getattr(fc, '__file__', None)\\ninfo['has_database_attr'] = hasattr(fc, 'database')\\ninfo['common_database_like_names'] = [n for n in dir(fc) if 'database' in n.lower() or n.lower() in ['db','database']]\\n\\np = Path('/root/fasthtml_toolbox/fasthtml_auth/database.py')\\ninfo['auth_database_py_exists'] = p.exists()\\ninfo['auth_database_py_head'] = p.read_text()[:800] if p.exists() else None\\ninfo\"})\n\nFile /usr/local/lib/python3.12/site-packages/ipykernel_helper/core.py:366, in call_tool(func, kw)\n    364 async def call_tool(func, kw):\n    365     \"Call `func(**kw)` with `coerce_inputs`\"\n--> 366     return await maybe_await(func(**coerce_inputs(func, kw)))\n\nFile /usr/local/lib/python3.12/site-packages/fastcore/xtras.py:1061, in maybe_await(o)\n   1059 \"Await `o` if needed, and return it\"\n   1060 from inspect import isawaitable\n-> 1061 return await o if isawaitable(o) else o\n\nFile /usr/local/lib/python3.12/site-packages/safepyrun/core.py:339, in RunPython.__call__(self, code)\n    337 tb = e.__traceback__\n    338 while tb.tb_next and not tb.tb_frame.f_code.co_filename.startswith('<pyrun'): tb = tb.tb_next\n--> 339 raise e.with_traceback(tb) from None\n\nFile <pyrun_0>:10\n      8     except Exception as e:\n      9         info[pkg] = f'not found: {type(e).__name__}'\n---> 10 info['fasthtml.common_file'] = getattr(fc, '__file__', None)\n     11 info['has_database_attr'] = hasattr(fc, 'database')\n     12 info['common_database_like_names'] = [n for n in dir(fc) if 'database' in n.lower() or n.lower() in ['db', 'database']]\n\nNameError: name 'getattr' is not defined"
# }
# ```
#
# </details>
#
# I can see the traceback points to `fasthtml_auth`, not your blog code directly: `fasthtml_auth/database.py` is doing `from fasthtml.common import database`, and the installed `fasthtml.common` no longer provides `database`. I’ll quickly inspect the installed package versions and the local auth helper file to confirm.
#
#
# <details class='tool-usage-details'>
# <summary><code>pyrun(code=&#x27;import importlib.metadata as md\nimport f…&#x27;)→&#x27;Traceback (most recent call last):\n\n  Fi…&#x27;</code></summary>
#
# ```json
# {
#   "id": "call_b3s4OXADBHSYFGO1pzLF5yQh",
#   "call": {
#     "function": "pyrun",
#     "arguments": {
#       "code": "import importlib.metadata as md\nimport fasthtml.common as fc\nfrom pathlib import Path\n\ninfo = {}\nfor pkg in ['python-fasthtml','fasthtml','fasthtml-auth','fasthtml_auth','fastlite']:\n    try:\n        info[pkg] = md.version(pkg)\n    except Exception as e:\n        info[pkg] = 'not found'\n\ninfo['fasthtml.common_file'] = fc.__dict__.get('__file__')\ninfo['has_database_attr'] = 'database' in fc.__dict__\ninfo['database_like_names'] = [n for n in fc.__dict__ if 'database' in n.lower()]\n\np = Path('/root/fasthtml_toolbox/fasthtml_auth/database.py')\ninfo['auth_database_py_exists'] = p.exists()\ninfo['auth_database_py_head'] = p.read_text()[:1000] if p.exists() else None\ninfo"
#     }
#   },
#   "result": "Traceback (most recent call last):\n\n  File /usr/local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3746 in run_code\n    await eval(code_obj, self.user_global_ns, self.user_ns)\n\n  Cell In[10], line 1\n    await call_tool(pyrun, {'code': \"import importlib.metadata as md\\nimport fasthtml.common as fc\\nfrom pathlib import Path\\n\\ninfo = {}\\nfor pkg in ['python-fasthtml','fasthtml','fasthtml-auth','fasthtml_auth','fastlite']:\\n    try:\\n        info[pkg] = md.version(pkg)\\n    except Exception as e:\\n        info[pkg] = 'not found'\\n\\ninfo['fasthtml.common_file'] = fc.__dict__.get('__file__')\\ninfo['has_database_attr'] = 'database' in fc.__dict__\\ninfo['database_like_names'] = [n for n in fc.__dict__ if 'database' in n.lower()]\\n\\np = Path('/root/fasthtml_toolbox/fasthtml_auth/database.py')\\ninfo['auth_database_py_exists'] = p.exists()\\ninfo['auth_database_py_head'] = p.read_text()[:1000] if p.exists() else None\\ninfo\"})\n\n  File /usr/local/lib/python3.12/site-packages/ipykernel_helper/core.py:366 in call_tool\n    return await maybe_await(func(**coerce_inputs(func, kw)))\n\n  File /usr/local/lib/python3.12/site-packages/fastcore/xtras.py:1061 in maybe_await\n    return await o if isawaitable(o) else o\n\n  File /usr/local/lib/python3.12/site-packages/safepyrun/core.py:339 in __call__\n    raise e.with_traceback(tb) from None\n\n  File /usr/local/lib/python3.12/site-packages/safepyrun/core.py:285 in run\n    if isinstance(e.msg, tuple): raise SyntaxError('\\n'.join(e.msg)) from None\n\n  File <string>\n    \nSyntaxError: Line 10: \"__dict__\" is an invalid attribute name because it starts with \"_\".\nLine 11: \"__dict__\" is an invalid attribute name because it starts with \"_\".\nLine 12: \"__dict__\" is an invalid attribute name because it starts with \"_\"."
# }
# ```
#
# </details>
#
# I can see the traceback: the failure is inside your local `fasthtml_auth` package, not in your blog code directly. It’s doing:
#
# ```python
# from fasthtml.common import database
# ```
#
# and your installed `fasthtml.common` no longer exports a name called `database`.
#
# I’m going to check the installed package versions and the local auth helper file, since this does look like a dependency/API drift issue. My first quick environment check hit the restricted tool sandbox’s limits (`getattr`/`__dict__` aren’t available there), so I’ll use simpler inspections.
#
#
# <details class='tool-usage-details'>
# <summary><code>pyrun(code=&#x27;import importlib.metadata as md\nversions…&#x27;)→&quot;{&#x27;python-fasthtml&#x27;: &#x27;not found&#x27;, &#x27;fastht…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_icZxSsYje0pskyLn1POp167S",
#   "call": {
#     "function": "pyrun",
#     "arguments": {
#       "code": "import importlib.metadata as md\nversions = {}\nfor pkg in ['python-fasthtml','fasthtml','fasthtml-auth','fasthtml_auth','fastlite']:\n    try:\n        versions[pkg] = md.version(pkg)\n    except Exception as e:\n        versions[pkg] = 'not found'\nversions"
#     }
#   },
#   "result": "{'python-fasthtml': 'not found', 'fasthtml': 'not found', 'fasthtml-auth': 'not found', 'fasthtml_auth': 'not found', 'fastlite': 'not found'}"
# }
# ```
#
# </details>
#
# I’ll inspect the local `fasthtml_auth` file that is failing and the installed `fasthtml.common` module to confirm whether `database` has disappeared or moved.
#
#
#
# <details class='tool-usage-details'>
# <summary><code>view(path=&#x27;/root/fasthtml_toolbox/fasthtml_auth/dat…&#x27;, nums=True)→&quot;Error viewing: PermissionError(13, &#x27;Perm…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_p3zoyARWqoAK4kZsWkuNYq7t",
#   "call": {
#     "function": "view",
#     "arguments": {
#       "path": "/root/fasthtml_toolbox/fasthtml_auth/database.py",
#       "nums": "True"
#     }
#   },
#   "result": "Error viewing: PermissionError(13, 'Permission denied')"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details'>
# <summary><code>rg(argstr=&#x27;&quot;def database|class Database|database =|…&#x27;, disallow_re=&#x27;$^&#x27;)→&#x27;/usr/local/lib/python3.12/site-packages/…&#x27;</code></summary>
#
# ```json
# {
#   "id": "call_5bUEfulM80MRh8syG56Uje58",
#   "call": {
#     "function": "rg",
#     "arguments": {
#       "argstr": "\"def database|class Database|database =|from fastlite|fastlite\" /usr/local/lib/python3.12/site-packages/fasthtml /usr/local/lib/python3.12/site-packages/fastlite* /root/fasthtml_toolbox -n",
#       "disallow_re": "$^"
#     }
#   },
#   "result": "/usr/local/lib/python3.12/site-packages/fasthtml/fastapp.py:78:    from fastlite import database\n\n/usr/local/lib/python3.12/site-packages/fastlite*: No such file or directory (os error 2)\n/root/fasthtml_toolbox: Permission denied (os error 13)"
# }
# ```
#
# </details>
#
#
#
#
#
# I found the key clue: your `fasthtml_auth` package is importing `database` from `fasthtml.common`, but the installed FastHTML package now appears to import `database` from `fastlite` internally. My metadata check couldn’t find a normal installed distribution name for these packages, and direct reading of your `/root/fasthtml_toolbox` file was blocked by permissions, but ripgrep found this line in FastHTML itself: `from fastlite import database` in `fasthtml/fastapp.py`. I’ll check that file location now to confirm the current expected import.
#
#
# <details class='tool-usage-details'>
# <summary><code>view(path=&#x27;/usr/local/lib/python3.12/site-packages/…&#x27;, view_range=[60, 95], nums=True)→&#x27;Error: Invalid end line 95&#x27;</code></summary>
#
# ```json
# {
#   "id": "call_RRc2Luv84qU3LMfAUCb7BWwJ",
#   "call": {
#     "function": "view",
#     "arguments": {
#       "path": "/usr/local/lib/python3.12/site-packages/fasthtml/fastapp.py",
#       "view_range": "[60, 95]",
#       "nums": "True"
#     }
#   },
#   "result": "Error: Invalid end line 95"
# }
# ```
#
# </details>
#
# I checked the local environment. Two useful findings so far:
#
# - The failing line is inside your local `/root/fasthtml_toolbox/fasthtml_auth/database.py`: `from fasthtml.common import database`.
# - The installed FastHTML code now appears to import `database` from `fastlite` instead — I found `from fastlite import database` in `fasthtml/fastapp.py`.
#
# I’ll inspect that FastHTML file and the installed package metadata a little more to confirm the likely replacement import.
#
#
#
# <details class='tool-usage-details'>
# <summary><code>rg(argstr=&#x27;&quot;from fastlite import database|database\…&#x27;, disallow_re=&#x27;$^&#x27;)→&#x27;/usr/local/lib/python3.12/site-packages/…&#x27;</code></summary>
#
# ```json
# {
#   "id": "call_mNWT9nDgmuNB7zpHtL6KlS2B",
#   "call": {
#     "function": "rg",
#     "arguments": {
#       "argstr": "\"from fastlite import database|database\\(\" /usr/local/lib/python3.12/site-packages/fasthtml -n",
#       "disallow_re": "$^"
#     }
#   },
#   "result": "/usr/local/lib/python3.12/site-packages/fasthtml/fastapp.py:78:    from fastlite import database\n/usr/local/lib/python3.12/site-packages/fasthtml/fastapp.py:79:    db = database(db_file)"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details'>
# <summary><code>pyrun(code=&#x27;import fasthtml.common as fc\nimport fast…&#x27;)→&quot;{&#x27;fasthtml_common_file&#x27;: &#x27;/usr/local/lib…&quot;</code></summary>
#
# ```json
# {
#   "id": "call_ZdwnmjoBb6kC8XsSoA1iezYi",
#   "call": {
#     "function": "pyrun",
#     "arguments": {
#       "code": "import fasthtml.common as fc\nimport fasthtml.fastapp as fa\nimport fastlite\n\nresult = {\n    'fasthtml_common_file': fc.__file__,\n    'fasthtml_fastapp_file': fa.__file__,\n    'fastlite_file': fastlite.__file__,\n    'common_has_database': 'database' in dir(fc),\n    'fastlite_has_database': 'database' in dir(fastlite),\n}\nresult"
#     }
#   },
#   "result": "{'fasthtml_common_file': '/usr/local/lib/python3.12/site-packages/fasthtml/common.py', 'fasthtml_fastapp_file': '/usr/local/lib/python3.12/site-packages/fasthtml/fastapp.py', 'fastlite_file': '/usr/local/lib/python3.12/site-packages/fastlite/__init__.py', 'common_has_database': False, 'fastlite_has_database': True}"
# }
# ```
#
# </details>
#
# Yes — the breakage is very likely due to a FastHTML / FastLite API change.
#
# The key error is:
#
# ```python
# ImportError: cannot import name 'database' from 'fasthtml.common'
# ```
#
# Your local `fasthtml_auth` package has this line:
#
# ```python
# from fasthtml.common import database
# ```
#
# But in the current installed FastHTML, `database` is no longer exported from `fasthtml.common`.
#
# I checked the installed package layout and found that FastHTML itself now imports it like this:
#
# ```python
# from fastlite import database
# ```
#
# Specifically, in the installed FastHTML:
#
# ```python
# /usr/local/lib/python3.12/site-packages/fasthtml/fastapp.py
# ```
#
# there is:
#
# ```python
# from fastlite import database
# db = database(db_file)
# ```
#
# So the likely fix is in:
#
# ```python
# ~/fasthtml_toolbox/fasthtml_auth/database.py
# ```
#
# change:
#
# ```python
# from fasthtml.common import database
# ```
#
# to:
#
# ```python
# from fastlite import database
# ```
#
# That should match the current FastHTML approach.
#
# One extra clue: your notebook already imports:
#
# ```python
# from fastlite import Database
# ```
#
# but `fasthtml_auth` is trying to import the lowercase `database` helper from the old place. So this looks like an upstream dependency/API drift issue rather than a problem in your blog code.
#
# <details class='token-usage-details'><summary>$0.0320</summary>
#
# `total=197,749 | in=193,789 | out=3,960 | cached=12.9% | reasoning=2,107 | searches=0 | $0.0320`
#
# </details>

# %% [markdown]
# #| export
# Core imports: `fastlite` for SQLite database, `fasthtml` and `monsterui` for web UI, `fasthtml_auth` for authentication, and `frontmatter` for parsing markdown with YAML metadata.

# %%
#| export
@dataclass
class AppState:
    pdb: Database # for managing posts
    posts_t: Table
    tags_t: Table
    post_tags_t: Table
    auth: AuthManager
    db: Database # For managing users and authorising access

# %% [markdown]
# #| export
# `AppState` holds all shared application state: the posts database, table references, and auth manager. Passed around instead of using globals.

# %%
#| export
def create_database_tables(pdb: Database # database to save posts and all associated tag tables
    ): 

    class Posts:
        id: int # primary key
        title: str # post title
        slug: str # unique slug based upon title
        content: str # The post content in markdown
        created: datetime # date and time created
        updated: datetime # date and time modified
        published: bool # is post published
        excerpt: str # short summary of the post
        private: bool # post only visible to logged in users

    posts = pdb.create(Posts, pk='id', defaults={'published': False, 'private':False}, transform=True)
    posts.create_index(['slug'], unique=True, if_not_exists=True)

    class Tags:
        id: int # primary key
        name: str # unique
    
    tags = pdb.create(Tags, pk='id', transform=True)
    tags.create_index(['name'], unique=True, if_not_exists=True)

    class PostTags:
        post_id: int # foreign key > posts.id
        tag_id: int # foreign key > tags.id
    
    post_tags = pdb.create(PostTags, pk=['post_id', 'tag_id'], transform=True)

# %% [markdown]
# #| export
# Creates the three database tables: `Posts` (blog content), `Tags` (category names), and `PostTags` (many-to-many junction table linking posts to tags).

# %%
#| export
def create_post_database(db_path: str # path to posts database
                        )-> Database: # Creates all the required database tables if they don't already exist
    pdb = Database(db_path)
    pdb.execute("PRAGMA foreign_keys = ON")
    create_database_tables(pdb)
    return pdb

# %% [markdown]
# Convenience wrapper that creates a database connection and initializes all tables.

# %%
#| export
yt_hdrs = (
    Script(f"""
function loadYouTube(el) {{
    var tmpl = document.getElementById('yt-template');
    var iframe = tmpl.content.firstElementChild.cloneNode(true);
    var id = el.getAttribute('data-video-id');
    iframe.src = "https://www.youtube.com/embed/" + id + "?autoplay=1&origin={config.ORIGIN}";
    el.replaceWith(iframe);
}}
"""),
    Template(
        Iframe(
            frameborder="0",
            allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share",
            referrerpolicy="strict-origin-when-cross-origin",
            allowfullscreen=True,
            cls="w-full aspect-video rounded-lg my-6",
            title="YouTube video player"
            ),
            id="yt-template"
    ),
)

# %%
#| export
def create_app():
    # Create databases and apps, return these within and AppState class.
    # Once created then create the server with srv = serve()
    # Add the routes with rt = app.route
    pdb = create_post_database(config.POSTS_DB_PATH)
    posts_t = pdb.t.posts
    tags_t = pdb.t.tags
    post_tags_t = pdb.t.post_tags
    # Initialize auth database
    auth = AuthManager(
        db_path=str(config.USERS_DB_PATH),
        config={
            'allow_registration': config.ALLOW_REGISTRATION,
            'public_paths': ['/', '/about', r'/blog.*', r'/post.*', '/googleada316577537ad2b.html', '/sitemap.xml'],  # Let anybody see the site apart from the admin and auth routes
            'login_path': '/auth/login',
        }
    )
    db = auth.initialize()
    # Set db password
    admin = auth.get_user(config.ADMIN_USERNAME)
    if admin and config.ADMIN_PASSWORD: auth.user_repo.update(admin.id, password=config.ADMIN_PASSWORD, email=config.ADMIN_EMAIL)
    beforeware = auth.create_beforeware()
    hdrs = (*Theme.blue.headers(highlightjs=True), Script(src="https://unpkg.com/hyperscript.org@0.9.12"),
        Script(src="https://www.googletagmanager.com/gtag/js?id=G-DP7YB96KHH", async_=True),
        Script("window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-DP7YB96KHH');"),
        *yt_hdrs,
        Link(rel="icon", type="image/png", href="/static/image/john_pixelated.png"))
    app = FastHTML(
        before=beforeware,
        secret_key=config.SECRET_KEY,
        hdrs=hdrs,
        exts='ws'  # Enable WebSocket support
    )
    config.STATIC_DIR.mkdir(parents=True, exist_ok=True)
    app.mount("/static", StaticFiles(directory=str(config.STATIC_DIR)), name="static")
    auth.setup_oauth(app=app, redirect_url=config.OAUTH_REDIRECT, allow_oauth_user_create=False)
    auth.register_routes(app, include_admin=True)
    state = AppState(
        pdb=pdb,
        posts_t=posts_t,
        tags_t=tags_t,
        post_tags_t=post_tags_t,
        auth=auth,
        db=db
    )
    return app, state

# %%
#| export
def create_app():
    # Create databases and apps, return these within and AppState class.
    # Once created then create the server with srv = serve()
    # Add the routes with rt = app.route
    pdb = create_post_database(config.POSTS_DB_PATH)
    posts_t = pdb.t.posts
    tags_t = pdb.t.tags
    post_tags_t = pdb.t.post_tags
    # Initialize auth database
    auth = AuthManager(
        db_path=str(config.USERS_DB_PATH),
        config={
            'allow_registration': config.ALLOW_REGISTRATION,
            'public_paths': ['/', '/about', r'/blog.*', r'/post.*', '/googleada316577537ad2b.html', '/sitemap.xml'],  # Let anybody see the site apart from the admin and auth routes
            'login_path': '/auth/login',
        }
    )
    db = auth.initialize()
    # Set db password
    admin = auth.get_user(config.ADMIN_USERNAME)
    if admin and config.ADMIN_PASSWORD: auth.user_repo.update(admin.id, password=config.ADMIN_PASSWORD, email=config.ADMIN_EMAIL)
    beforeware = auth.create_beforeware()
    hdrs = (*Theme.blue.headers(highlightjs=True), Script(src="https://unpkg.com/hyperscript.org@0.9.12"),
        Script(src="https://www.googletagmanager.com/gtag/js?id=G-DP7YB96KHH", async_=True),
        Script("window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-DP7YB96KHH');"),
        Script("""
function loadYouTube(el) {
    var tmpl = document.getElementById('yt-template');
    var iframe = tmpl.content.firstElementChild.cloneNode(true);
    var id = el.getAttribute('data-video-id');
    iframe.src = "https://www.youtube-nocookie.com/embed/" + id + "?autoplay=1&origin=" + window.location.origin;
    el.replaceWith(iframe);
}
"""),
        Template(
            Iframe(
                frameborder="0",
                allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share",
                referrerpolicy="strict-origin-when-cross-origin",
                allowfullscreen=True,
                cls="w-full aspect-video rounded-lg my-6",
                title="YouTube video player"
            ),
            id="yt-template"
        ),
        Link(rel="icon", type="image/png", href="/static/image/john_pixelated.png"))
    app = FastHTML(
        before=beforeware,
        secret_key=config.SECRET_KEY,
        hdrs=hdrs,
        exts='ws'  # Enable WebSocket support
    )
    config.STATIC_DIR.mkdir(parents=True, exist_ok=True)
    app.mount("/static", StaticFiles(directory=str(config.STATIC_DIR)), name="static")
    auth.setup_oauth(app=app, redirect_url=config.OAUTH_REDIRECT, allow_oauth_user_create=False)
    auth.register_routes(app, include_admin=True)
    state = AppState(
        pdb=pdb,
        posts_t=posts_t,
        tags_t=tags_t,
        post_tags_t=post_tags_t,
        auth=auth,
        db=db
    )
    return app, state

# %% [markdown]
# #| export
# Main app factory: initializes both databases, sets up authentication with `fasthtml-auth`, configures headers and static files, and returns the app plus an `AppState` instance.

# %%
#| export
# Route collection for deferred registration
_routes = []

def route(path=None):
    """Decorator to collect routes without registering them immediately.
    Use @route('/path') or @route() for function-name-based paths."""
    def decorator(f):
        _routes.append((path, f))
        return f
    if callable(path):  # @route without parens
        f, path = path, None
        _routes.append((path, f))
        return f
    return decorator

# %% [markdown]
# #| export
# Route collector decorator. Stores routes in `_routes` list for later registration. Supports both `@route` (path from function name) and `@route('/custom/path')` syntax.

# %%
#| export
def register_routes(app):
    """Register all collected routes with the app."""
    for path, handler in _routes:
        if path:
            app.route(path)(handler)
        else:
            app.route(handler)

# %% [markdown]
# #| export
# Registers all routes collected by `@route` with the given app. Call this in your `app.py` after importing the module.

# %%
#| export
@route(f"/admin/logout")
def logout(sess):
    """ Overwrite logout route from fasthtml_auth to return users to home page after logging out
    """
    print("MY LOGOUT CALLED")
    sess.clear()
    return Response(status_code=200, headers={"HX-Redirect": "/"})

# %%
#| export
def intro():
    return Article(
        H3("Welcome to my Blog Site", cls="text-2xl font-semibold mb-4"),
        Div(cls="text-base gap-1 text-muted-foreground leading-relaxed space-y-4")(
        P("I created this site to keep a record of things I am interested in.  As such it will largely cover motorhome trips, cycling events and routes that I have done and enjoyed, coding and software development activities I am interested in or engaged with, and technology that I think is worth looking at.  You can find out more about me on my ", hx_link("About", "/about"), " page"),

        P("This site is developed using fastHTML and the Solveit platform, both technologies developed by Jeremy Howard and ",A('Answer.ai', href='https://answer.ai', target="_blank", rel="noopener noreferrer", cls="text-primary underline"), " The desgn was originally based upon the site of ", A('Jack Hogan.', href='https://jackhogan.net/', target="_blank", rel="noopener noreferrer", cls="text-primary underline"), "but has evolved to be database driven for both users and posts, as well as to incorporate infinite scroll amongst other things"

        " See my latest blog posts below or find the full list on my ", hx_link("Blog", "/blog"), " page, where posts can be readily filtered by topic.")
        )
    )

# %% [markdown]
# #| export
# Homepage intro section: returns an `Article` with welcome text and links to About and Blog pages using HTMX-enabled navigation.

# %%
#| export
def hx_attrs(target="#main-content"): return dict(hx_target=target, hx_push_url="true", hx_swap="innerHTML show:window:top")

def hx_link(txt, href, cls="text-primary underline", target="#main-content", **kw):
    # Utility function to configure the update of the target (by default the #main-content) using hx_get. Falls back to html if not htmx
    return A(txt, href=href, hx_get=href, cls=cls, **hx_attrs(target), **kw)

# %% [markdown]
# This dialogue is part of an nbdev project.  When deployed to github the actions setup for publishing to github pages is resulting in two entries for this dialogue (see: https://fromlittleacorns.github.io/my-blog/). Can you use dialogue tools to explore why this might be happening

# %% [markdown]
# Yes please create the sidebar file.  The pages looks like this:
#
# ![image.png](attachment:8fca75ad-5587-433c-a5a9-354f8590f2bf)
#
# You can see the duplication there

# %% [markdown]
# #| export
# `hx_attrs` returns HTMX attributes for partial page updates. `hx_link` creates an anchor that uses both regular `href` and HTMX `hx-get` for SPA-like navigation.

# %%
#| export
def is_logged_in(req):
    auth_user_name = req.scope.get('session', {}).get('auth')
    return True if auth_user_name else False

# %%
#| export
def navbar(req: Request):
    # Check if logged in user
    logged_in = is_logged_in(req)
    if logged_in:
        log_link = hx_link(UkIcon("user"), "/admin/logout") 
    else:
        log_link = A(UkIcon('log-in'), href="/auth/login", cls="uk-button uk-button-default uk-button-xs")
    brand = A(Img(src="/static/image/john_pixelated.png", alt="John Richmond", cls="w-6 h-6 rounded-full"), Span("John Richmond "), href="/", hx_get="/", cls="flex items-center gap-2 text-lg font-bold", **hx_attrs())
    links = Div(hx_link("About", "/about"), hx_link("Blog", "/blog"), log_link, cls="flex gap-4 items-center")
    return Nav(Div(brand, links, cls="flex items-center gap-2 justify-between p-4"), cls="border rounded-lg shadow bg-background")

# %% [markdown]
# #| export
# Navigation bar with brand logo/name on the left and page links (About, Blog) on the right. Uses flexbox for layout.

# %%
#| export
def x_icon(): return Svg(ft_hx("path", d="M12.6.75h2.454l-5.36 6.142L16 15.25h-4.937l-3.867-5.07-4.425 5.07H.316l5.733-6.57L0 .75h5.063l3.495 4.633L12.601.75Zm-.86 13.028h1.36L4.323 2.145H2.865z"), width=20, height=20, fill="currentColor", viewBox="0 0 16 16", aria_hidden="true")

# %% [markdown]
# #| export
# Custom X (Twitter) icon as inline SVG—UIkit doesn't include the new X logo.

# %%
#| export
def social_link(icon, href, **kw):
    kw = dict(rel="nofollow noindex") if k == "mail" else dict(target="_blank", rel="noopener noreferrer")
    return A(x_icon() if k == "twitter" else UkIcon(icon, width=20, height=20), href=href, cls="hover:text-primary transition-colors", target="_blank", rel="noopener noreferrer", **kw)

def social_link(k, v):
    ext = dict(rel="nofollow noindex") if k == "mail" else {} if k == "rss" else dict(target="_blank", rel="noopener noreferrer")
    return A(x_icon() if k == "twitter" else UkIcon(k, width=20, height=20), href=v, aria_label=k.title(), cls="hover:text-primary transition-colors", **ext)


def footer():
    links = dict(twitter="https://x.com/@johnWrichmond", youtube="https://youtube.com/@confusedjohn46a", github="https://github.com/fromLittleAcorns")
    icons = Div(*[social_link(k, v) for k, v in links.items()], social_link("mail", "mailto:confusedjohn46@gmail.com"), cls="flex justify-center gap-6 text-muted-foreground")
    return Footer(Divider(), icons, cls="max-w-2xl mx-auto px-6 mt-auto mb-6")

# %% [markdown]
# #| export
# `social_link` creates social media icon links with appropriate `rel` attributes for security. `footer` assembles the page footer with social icons.

# %%
#| export
def layout(req, *content, htmx, title=None):
    ''' title here is used to set the browser tab label in the <head> section and will not be visible on the page.  The article title is appended into the main content and shows below the navbar
    '''
    if htmx and htmx.request: return (Title(title), *content)
    main = Main(*content, cls='w-full max-w-2xl mx-auto px-6 py-8 space-y-8', id="main-content")
    return Title(title), Div(Div(navbar(req), cls='max-w-2xl mx-auto px-4 mt-4'), main, footer(), cls="flex flex-col min-h-screen")

# %% [markdown]
# #| export
# Page layout wrapper. On HTMX requests, returns just the content (for partial swap). On full page loads, wraps content with navbar and footer.

# %%
#| export
def slug_exists(slug):
    if bool(list(state.posts_t.rows_where("slug = ?", [slug], limit=1))):
        return list(state.posts_t.rows_where("slug = ?", [slug], limit=1))[0]['id']
    else:
        return False

# %% [markdown]
# #| export
# Checks if a slug already exists in the database. Returns the post ID if found, `False` otherwise. Used for update-vs-insert logic.

# %%
from datetime import datetime

# %%
#| export
def get_slug(title):
    slug = title.lower().replace(" ", "-")
    slug = ''.join(c for c in slug if c.isalnum() or c == '-')[:60]
    return slug

# %% [markdown]
# # Example: add a post
# add_post(
#     title="My First Post",
#     content="This is the **content** in markdown.",
#     excerpt="A short summary",
#     tags=["coding", "technology"]
# )

# %% [markdown]
# #| export
# Creates or updates a post. Generates slug from title, handles tag creation/linking in the junction table. Updates existing posts if slug matches.

# %%
#| export
@route('/blog/{slug}')
def blogpost(htmx, req, slug: str):
    is_admin = check_if_admin(req)
    logged_in = is_logged_in(req)
    row = state.posts_t.rows_where("slug = ?", [slug], limit=1)
    p = next((dict(r) for r in row), None)
    if not p:
        return layout(req, H2("Not Found"), P("Post not found."), title="Not Found", htmx=htmx)
    if p.get('private') and not logged_in:
        return layout(req, H2("Not Found"), P("Please login to access this post."), title="Private post", htmx=htmx)
    p['created'] = datetime.fromisoformat(p['created']) if isinstance(p['created'], str) else p['created']
    image_base = f"/static/image/post_images/{slug}"
    content = preprocess_markdown(p['content'], image_base=image_base)
    content = render_md(content, renderer=EnhancedRenderer)
    content = Div(content, uk_lightbox="animation: slide")
    content = process_strava_embeddings(content)
    content = process_komoot_embed(content)
    content = process_bunny_embed(content, slug)
    # content = process_you_tube_embed(content)
    admin_btns = Div(
        A("Edit", href=f'/admin/edit/{slug}', cls="uk-btn uk-btn-default uk-btn-xs"),
        # Button("Delete", hx_post=f"/admin/delete/{p['slug']}", hx_confirm="Delete this post?", 
        #    cls=["uk-btn uk-btn-default uk-btn-xs"]),
        Button("Delete", hx_post=f"/admin/delete/{slug}", hx_confirm="Delete this post?", 
            hx_swap="innerHTML", cls="uk-btn uk-btn-default uk-btn-xs"),
        A("Download", href=f"/admin/download/{p['slug']}", cls=[ButtonT.default, "uk-btn-xs"]),
        cls='flex gap-1'
    ) if is_admin else Div()
    return layout(req, H1(p['title'], cls="text-3xl font-bold mb-2"), Span(p['created'].strftime('%B %d, %Y'), cls="text-muted-foreground text-sm mb-8 block"), content, 
    admin_btns, Script(src="https://strava-embeds.com/embed.js"), title=p['title'], htmx=htmx)

# %% [markdown]
# #| export
# Route to display a single blog post. Fetches by slug, parses the datetime, renders markdown content with `render_md`, processes Obsidian images and Strava embeds.

# %% [markdown]
# In the above the images display properly but I would like to make it possible that when a user clicks upon an image it pops out at higher resolution in front of the existing page, and when closed the user is taken back to the earlier page.  I think there is a facility to do this using MonsterUI, can you suggest the process I would need to follow
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great idea! UIkit (which MonsterUI is built on) has a built-in lightbox component called `uk-lightbox`. The way it works is:
#
# 1. You wrap your images in a container with the `uk-lightbox` attribute
# 2. Each image is wrapped in an anchor (`<a>`) pointing to the full-resolution image
# 3. UIkit handles the click-to-open and close-to-return behavior automatically
#
# Since your images are already processed in `process_obsidian_images` (I spotted that in your code), you'd modify that function to wrap each image in a link to its full-resolution source, and wrap the whole post content (or just the image block) with the lightbox container.
#
# A typical pattern in MonsterUI/FastHTML looks like:
#
# ```python
# from monsterui.all import *
#
# # Wrap the image in a link to the full-size version
# A(Img(src=thumbnail_path, cls="..."), href=full_size_path, data_type="image")
# ```
#
# And wrap the container with `Lightbox` or add `uk-lightbox` as an attribute.
#
# Do you want me to look at your `process_obsidian_images` function specifically and show you the exact changes you'd need to make? If so, could you share that function's code?
#
# <details class='token-usage-details'><summary>$0.0277</summary>
#
# `total=26,557 | in=25,900 | out=657 | cached=73.3% | reasoning=397 | searches=0 | $0.0277`
#
# </details>

# %% [markdown]
# Yes please
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <details class='tool-usage-details'>
# <summary><code>find_msgs(re_pattern=&#x27;process_obsidian_images&#x27;)→&quot;[{&#x27;id&#x27;: &#x27;_b7dbd6e5&#x27;, &#x27;time_run&#x27;: &#x27;2026-0…&quot;</code></summary>
#
# ```json
# {
#   "id": "functions.find_msgs:0",
#   "call": {
#     "function": "find_msgs",
#     "arguments": {
#       "re_pattern": "process_obsidian_images"
#     }
#   },
#   "result": "<TRUNCATED>\u2026b7dbd6e5', 'time_run': '2026-05-11T08:01:38.532184+00:00', 'is_exported': False, 'skipped': False, 'bookmark': {}, 'i_collapsed': False, 'o_collapsed': False, 'heading_collapsed': False, 'i_clamp': False, 'o_clamp': False, 'pinned': False, 'run': {}, 'content': \"await call_tool(find_msgs, {'re_pattern': 'process_obsidian_images'})\", 'output': '', 'msg_type': 'code', 'input_tokens': 88, 'output_tokens': {}}, {'id': '_ffe15f8f', 'time_run': '', 'is_exported': 0, 'skipped': 0, 'bookmark': {}, 'i_collapsed': 1, 'o_collapsed': 0, 'heading_collapsed': False, 'i_clamp': False, 'o_clamp': False, 'pinned': 0, 'run': {}, 'content': 'def process_obsidian_images(page: NotStr, image_base: str) -> NotStr:\\n    page = str(page)\\n    pattern = new3 = r\\'\\'\\'!\\\\[\\\\[(?P[^\\\\]]+\\\\.(jpg|jpeg|png|gif|svg)) # Image part, must be present\\n(?:\\\\|(?P<size1>\\\\d+))? # First size dimension (with leading pipe symbol (optional)\\n(?:x(?P<size2>\\\\d+))? # Second size dimension (with leading x)\\n(?:\\\\|(?P<location>left|right|center))?\\n\\\\]\\\\] # End of image (must be present)\\n\\'\\'\\'\\n    \\n    for match in re.finditer(pattern, page, re.MULTILINE + re.VERBOSE):\\n        m = match.groupdict()\\n        \\n        # 1. Build src path\\n        src = f\"{image_base}/{m[\\'image\\']}\"\\n        \\n        # 2. Build style string from size1, size2, location\\n        styles = []\\n        if m[\\'size1\\']:\\n            styles.append(f\"width: {m[\\'size1\\']}px\")\\n        if m[\\'size2\\']:\\n            styles.append(f\"height: {m[\\'size2\\']}px\")\\n        if m[\\'location\\'] == \\'center\\':\\n            styles.append(\"display: block; margin: auto\")\\n        elif m[\\'location\\'] == \\'right\\':\\n            styles.append(\"float: right; margin-left: 1rem\")\\n        elif m[\\'location\\'] == \\'left\\':\\n            styles.append(\"float: left; margin-right: 1rem\")\\n        \\n        style_str = \"; \".join(styles)\\n        \\n        # 3. Build img tag and replace\\n        img_tag = f\\'<img src=\"{src}\" style=\"{style_str}\">\\'\\n        page = page.replace(match.group(0), img_tag)\\n    \\n    return NotStr(page)', 'output': '', 'msg_type': 'raw', 'input_tokens': 571, 'output_tokens': {}}, {'id': '_db6b3b98', 'time_run': '', 'is_exported': 1, 'skipped': 0, 'bookmark': {}, 'i_collapsed': 1, 'o_collapsed': 0, 'heading_collapsed': False, 'i_clamp': False, 'o_clamp': False, 'pinned': 0, 'run': {}, 'content': 'def _process_standalone_images(content: str, image_base: str) -> str:\\n    \"\"\"Process remaining ![[image]] without captions into <img> tags\"\"\"\\n    # Same as your current process_obsidian_images but for markdown (not HTML)\\n    pattern = r\\'\\'\\'\\n        !\\\\[\\\\[(?P[^\\\\]\\\\n]+\\\\.(?:jpg|jpeg|png|gif|svg))\\n        (?:\\\\|(?P<size1>\\\\d+))?\\n        (?:x(?P<size2>\\\\d+))?\\n        (?:\\\\|(?P<location>left|right|center))?\\n        \\\\]\\\\]\\n        (?!\\\\n>)  # Negative lookahead: not followed by newline + >\\n    \\'\\'\\'\\n    \\n    def make_image(match):\\n        m = match.groupdict()\\n        src = f\"{image_base}/{m[\\'image\\']}\"\\n        \\n        styles = []\\n        if m[\\'size1\\']:\\n            styles.append(f\"width: {m[\\'size1\\']}px\")\\n        if m[\\'size2\\']:\\n            styles.append(f\"height: {m[\\'size2\\']}px\")\\n        if m[\\'location\\'] == \\'center\\':\\n            styles.append(\"display: block; margin: auto\")\\n        elif m[\\'location\\'] == \\'right\\':\\n            styles.append(\"float: right; margin-left: 1rem\")\\n        elif m[\\'location\\'] == \\'left\\':\\n            styles.append(\"float: left; margin-right: 1rem\")\\n        \\n        style_str = \"; \".join(styles)\\n        return f\\'<img src=\"{src}\" style=\"{style_str}\">\\' if styles else f\\'<img src=\"{src}\">\\'\\n    \\n    return re.sub(pattern, make_image, content, flags=re.MULTILINE + re.VERBOSE)', 'output': '', 'msg_type': 'raw', 'input_tokens': 536, 'output_tokens': {}}, {'id': '_907bde85', 'time_run': '', 'is_exported': 1, 'skipped': 0, 'bookmark': {}, 'i_collapsed': 0, 'o_collapsed': 0, 'heading_collapsed': False, 'i_clamp': False, 'o_clamp': False, 'pinned': 0, 'run': {}, 'content': 'def process_obsidian_images(content: str, image_base: str) -> str:\\n    pattern = r\\'\\'\\'\\n        !\\\\[\\\\[(?P[^\\\\]\\\\n]+\\\\.(?:jpg|jpeg|png|gif|svg))\\n        (?:\\\\|(?P<size1>\\\\d+))?\\n        (?:x(?P<size2>\\\\d+))?\\n        (?:\\\\|(?P<location>left|right|center))?\\n        \\\\]\\\\]\\n        (?:\\\\n>\\\\s*(?P<caption>[^\\\\n]+))?\\n    \\'\\'\\'\\n\\n    def make_element(match):\\n        m = match.groupdict()\\n        src = f\"{image_base}/{m[\\'image\\']}\"\\n        loc = m.get(\\'location\\')\\n\\n        img_styles = []\\n        if m[\\'size1\\']: img_styles.append(f\"width: {m[\\'size1\\']}px\")\\n        if m[\\'size2\\']: img_styles.append(f\"height: {m[\\'size2\\']}px\")\\n\\n        wrap_styles = []\\n        if loc == \\'right\\':    wrap_styles = [\\'float: right\\', \\'margin-left: 1rem\\']\\n        elif loc == \\'left\\':   wrap_styles = [\\'float: left\\', \\'margin-right: 1rem\\']\\n        elif loc == \\'center\\': wrap_styles = [\\'display: block\\', \\\u2026</TRUNCATED>"
# }
# ```
#
# </details>
#
#
#
#
#
#
#
#
# <details class='tool-usage-details'>
# <summary><code>view_msg(id=&#x27;_907bde85&#x27;, nums=True)→&#x27;1 │ def process_obsidian_images(content:…&#x27;</code></summary>
#
# ```json
# {
#   "id": "functions.view_msg:1",
#   "call": {
#     "function": "view_msg",
#     "arguments": {
#       "id": "_907bde85",
#       "nums": "True"
#     }
#   },
#   "result": "1 \u2502 def process_obsidian_images(content: str, image_base: str) -> str:\n     2 \u2502     pattern = r'''\n     3 \u2502         !\\[\\[(?P[^\\]\\n]+\\.(?:jpg|jpeg|png|gif|svg))\n     4 \u2502         (?:\\|(?P<size1>\\d+))?\n     5 \u2502         (?:x(?P<size2>\\d+))?\n     6 \u2502         (?:\\|(?P<location>left|right|center))?\n     7 \u2502         \\]\\]\n     8 \u2502         (?:\\n>\\s*(?P<caption>[^\\n]+))?\n     9 \u2502     '''\n    10 \u2502 \n    11 \u2502     def make_element(match):\n    12 \u2502         m = match.groupdict()\n    13 \u2502         src = f\"{image_base}/{m['image']}\"\n    14 \u2502         loc = m.get('location')\n    15 \u2502 \n    16 \u2502         img_styles = []\n    17 \u2502         if m['size1']: img_styles.append(f\"width: {m['size1']}px\")\n    18 \u2502         if m['size2']: img_styles.append(f\"height: {m['size2']}px\")\n    19 \u2502 \n    20 \u2502         wrap_styles = []\n    21 \u2502         if loc == 'right':    wrap_styles = ['float: right', 'margin-left: 1rem']\n    22 \u2502         elif loc == 'left':   wrap_styles = ['float: left', 'margin-right: 1rem']\n    23 \u2502         elif loc == 'center': wrap_styles = ['display: block', 'margin: auto']\n    24 \u2502 \n    25 \u2502         # elif loc == 'center': wrap_styles = ['display: block', 'margin: auto', 'text-align: center']\n    26 \u2502 \n    27 \u2502         caption = m.get('caption')\n    28 \u2502         if caption:\n    29 \u2502             wrap_style = f' style=\"{\"; \".join(wrap_styles)}\"' if wrap_styles else ''\n    30 \u2502             img_style = f' style=\"{\"; \".join(img_styles)}\"' if img_styles else ''\n    31 \u2502             return (f'<figure{wrap_style}>\\n'\n    32 \u2502                     f'<img src=\"{src}\"{img_style}>\\n'\n    33 \u2502                     f'<figcaption style=\"font-size:0.85em; color:#666; text-align:center\">{caption.strip()}</figcaption>\\n'\n    34 \u2502                     f'</figure>')\n    35 \u2502 \n    36 \u2502         all_styles = img_styles + wrap_styles\n    37 \u2502         style = f' style=\"{\"; \".join(all_styles)}\"' if all_styles else ''\n    38 \u2502         return f'<img src=\"{src}\"{style}>'\n    39 \u2502 \n    40 \u2502     return re.sub(pattern, make_element, content, flags=re.MULTILINE + re.VERBOSE)"
# }
# ```
#
# </details>
#
#
#
#
#
# Here is your `process_obsidian_images` function. I can see it builds raw `<img>` tags for both captioned and uncaptioned images.
#
# To add lightbox support with UIkit (which MonsterUI uses under the hood), you need two small changes:
#
# **1. Wrap each generated image in an anchor tag** inside `process_obsidian_images`, so UIkit knows what to open when clicked.
#
# **2. Optionally group them** so users can navigate between post images with arrow keys.
#
# The exact spots to change are lines 31-34 (caption case) and line 38 (plain image case).
#
# Would you like me to show you the replacement code for those specific lines? Or would you prefer to try the edit yourself first based on this pattern?
#
# ```html
# <a href="full-image.jpg" data-type="image" data-uk-lightbox="{group: post-images}">
#     <img src="thumbnail-or-sized-image.jpg" style="...">
# </a>
# ```
#
# One note: are your Obsidian images already uploaded at full resolution (which the browser then scales down with CSS), or do you have separate thumbnail files? This affects whether the `href` should point to the same file or a larger version.
#
# <details class='token-usage-details'><summary>$0.0655</summary>
#
# `total=87,705 | in=84,995 | out=2,710 | cached=92.0% | reasoning=2,435 | searches=0 | $0.0655`
#
# </details>

# %% [markdown]
# They are uploaded at full resolution
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Since they're full resolution, the `href` and `src` can point to the same file. The browser shows the CSS-sized version, and the lightbox opens the full image.
#
# Here are the two changes to make inside `make_element`:
#
# **For the captioned figure (around line 31-34):**
# ```python
# return (f'<figure{wrap_style}>\n'
#         f'<a href="{src}" data-type="image" data-uk-lightbox="group: post"><img src="{src}"{img_style}></a>\n'
#         f'<figcaption style="font-size:0.85em; color:#666; text-align:center">{caption.strip()}</figcaption>\n'
#         f'</figure>')
# ```
#
# **For the plain image (around line 38):**
# ```python
# return f'<a href="{src}" data-type="image" data-uk-lightbox="group: post"><img src="{src}"{style}></a>'
# ```
#
# The `data-uk-lightbox="group: post"` attribute groups all images in the post into one lightbox gallery, so users can navigate between them with arrow keys.
#
# Would you like me to apply these changes directly to your `process_obsidian_images` cell, or would you prefer to make them yourself?
#
# <details class='token-usage-details'><summary>$0.0287</summary>
#
# `total=30,442 | in=28,937 | out=1,505 | cached=90.0% | reasoning=1,247 | searches=0 | $0.0287`
#
# </details>

# %% [markdown]
# Can we make the above changes using more native fastHTML and monsterui instead of going straight to the html.  In an earlier example you used A(Img(src...
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes, absolutely. Since you already have `from fasthtml.common import *` and `from monsterui.all import *`, you can use `A(Img(...))` directly instead of building raw HTML strings. FastHTML components convert neatly to strings with `str()`.
#
# Here is how you would rewrite just the two return points inside `make_element`:
#
# **For the captioned figure (replacing lines 28-34):**
#
# ```python
#         if caption:
#             fig_style = "; ".join(wrap_styles) if wrap_styles else None
#             img_tag = Img(src=src, style="; ".join(img_styles)) if img_styles else Img(src=src)
#             return str(Figure(style=fig_style)(
#                 A(img_tag, href=src, data_type="image", data_uk_lightbox="group: post"),
#                 Figcaption(caption.strip(), style="font-size:0.85em; color:#666; text-align:center")
#             ))
# ```
#
# **For the plain image (replacing lines 36-38):**
#
# ```python
#         all_styles = img_styles + wrap_styles
#         img_tag = Img(src=src, style="; ".join(all_styles)) if all_styles else Img(src=src)
#         return str(A(img_tag, href=src, data_type="image", data_uk_lightbox="group: post"))
# ```
#
# A few things to note:
# - `Figure` and `Figcaption` come from `fasthtml.common` (they are standard HTML5 tags).
# - FastHTML automatically turns underscores into hyphens in attributes, so `data_type` becomes `data-type` and `data_uk_lightbox` becomes `data-uk-lightbox`.
# - By putting `data_uk_lightbox` directly on each `A`, you do not need a wrapper container.
#
# Would you like me to apply these two replacements directly into your `_907bde85` cell?
#
# <details class='token-usage-details'><summary>$0.0743</summary>
#
# `total=34,229 | in=29,232 | out=4,997 | cached=65.0% | reasoning=4,643 | searches=0 | $0.0743`
#
# </details>

# %% [markdown]
# I have made the changes but when I run the code I am seeing a hyperlink when I hover over one of the images, but then when I click on the link nothing is happening
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Most likely the lightbox attribute is on the wrong element.
#
# For UIkit/MonsterUI lightbox, the usual pattern is:
#
# ```python
# Div(A(Img(src=src), href=src), uk_lightbox=True)
# ```
#
# i.e. `uk-lightbox` goes on a **container**, and the clickable images inside are ordinary `<a href="full-image">...</a>` links.
#
# So instead of putting this on every `A`:
#
# ```python
# data_uk_lightbox="group: post"
# ```
#
# try making the generated image link simpler:
#
# ```python
# A(Img(src=src, style=...), href=src)
# ```
#
# Then in your `blogpost` route, wrap the rendered post content:
#
# ```python
# content = Div(content, uk_lightbox="animation: slide")
# ```
#
# before passing it into `layout`.
#
# So the relevant section would become roughly:
#
# ```python
# content = render_md(content, renderer=EnhancedRenderer)
# content = process_strava_embeddings(content)
# content = Div(content, uk_lightbox="animation: slide")
# ```
#
# Why this matters: UIkit scans the children of the `uk-lightbox` element for links to images. If the attribute is directly on the `<a>` itself, it may initialise the component but find no child links to open, so the hover looks right but the click appears to do nothing.
#
# <details class='token-usage-details' markdown='1'><summary>$0.0062</summary>
#
# `total=37,858 | in=37,062 | out=796 | cached=5.2% | reasoning=516 | searches=0 | $0.0062`
#
# </details>

# %% [markdown]
# So the image would still have the data_type="image" but not the data_uk_lightbox="group: post", is that correct?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes — that’s right.
#
# For each image link, keep something like:
#
# ```python
# A(Img(src=src, style=...), href=src, data_type="image")
# ```
#
# but remove:
#
# ```python
# data_uk_lightbox="group: post"
# ```
#
# Then put the lightbox attribute on a parent/container that wraps the rendered post content, e.g. in `blogpost` after rendering/processing:
#
# ```python
# content = Div(content, uk_lightbox="animation: slide")
# ```
#
# So: individual links say “this opens an image”; the parent container says “treat child image links as a lightbox gallery.”
#
# <details class='token-usage-details' markdown='1'><summary>$0.0056</summary>
#
# `total=37,040 | in=36,907 | out=133 | cached=5.2% | searches=0 | $0.0056`
#
# </details>
# b

# %% [markdown]
# Why add the Div after the process_strava but before the other process functions? I have put it directly after the render_md, should that be ok?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes, putting it directly after `render_md` **can be OK**, as long as the later processing functions preserve that wrapper.
#
# The lightbox only needs this final HTML structure:
#
# ```html
# <div uk-lightbox="animation: slide">
#   <a href="full-image.jpg" data-type="image"><img ...></a>
# </div>
# ```
#
# So the key rule is: the `uk_lightbox` `Div` must still be a **parent/ancestor** of the image links in the final rendered page.
#
# That said, the most robust place is usually **after all content-processing functions**, just before returning the layout:
#
# ```python
# content = process_bunny_embed(content, slug)
# content = Div(content, uk_lightbox="animation: slide")
# ```
#
# Why? Because if `process_strava_embeddings`, `process_komoot_embed`, or `process_bunny_embed` rebuilds or replaces the content object, it might accidentally remove or bypass the earlier wrapper.
#
# So:
#
# - Directly after `render_md`: fine if the later processors preserve the wrapper.
# - After all processors: safest and clearest.
#
# <details class='token-usage-details' markdown='1'><summary>$0.0062</summary>
#
# `total=38,389 | in=37,645 | out=744 | cached=5.1% | reasoning=516 | searches=0 | $0.0062`
#
# </details>

# %% [markdown]
# Before we do so what do i need to do with wrap_styles

# %%
#| export
@route
def index(req, htmx):
    logged_in = is_logged_in(req)
    posts = get_posts(n=6, logged_in=logged_in)
    items = [A(H3(p['title']), P(p['excerpt'], cls="text-muted-foreground"), Span(p['created'].strftime('%d %b %Y'), cls="text-sm text-muted-foreground"), href=f"/blog/{p['slug']}", hx_get=f"/blog/{p['slug']}", cls="block border-b pb-4 hover:bg-muted/50 transition-colors", **hx_attrs()) for p in posts]
    content = Div(*items, cls="space-y-4") if items else P("No posts yet.", cls="text-muted-foreground")
    return layout(req, (intro(), Divider(), Section(H3("Latest Posts", cls="text-xl font-semibold mb-4"), content)), title="Welcome to my Blog", htmx=htmx)

# %% [markdown]
# #| export
# Homepage route: displays intro section, a divider, and the latest posts as cards.

# %%
#| export
def get_tags(tags_tbl):
    tags = [row.name for row in tags_tbl()]
    return tags

# %% [markdown]
# #| export
# Returns all tag names from the tags table as a list.

# %%
#| export
def get_post_tags(post_id: int):
    query = """
    SELECT name FROM tags WHERE id IN (SELECT tag_id FROM post_tags WHERE post_id=?)
    """
    tag_name_dicts = state.pdb.q(query, [post_id])
    tag_names = [name['name'] for name in tag_name_dicts]
    return tag_names

# %% [markdown]
# #| export
# Fetches all tags associated with a specific post via the `post_tags` junction table.

# %% [raw]
# def get_posts(n: Union[int, None]=None, tags: Union[List, None] = None, logged_in: bool=False):
#     if tags:
#         place_holders = ','.join('?' * len(tags))
#         private_posts_query = '' if logged_in else 'AND p.private = False '
#         query = f"""
#             SELECT DISTINCT p.* FROM posts p
#             JOIN post_tags pt ON p.id = pt.post_id
#             JOIN tags t ON pt.tag_id = t.id
#             WHERE t.name IN ({place_holders}) AND p.published = True {private_posts_query}
#             ORDER BY p.created DESC
#         """
#         if n: query += f" LIMIT {n}"
#         posts = state.pdb.q(query, tags)
#     else:
#         posts = list(state.posts_t.rows_where("published = ? AND (private = False OR ?)", [True, logged_in], order_by="created DESC", limit=n))
#         posts = [dict(r) for r in posts]
#
#     for p in posts:
#         p['created'] = datetime.fromisoformat(p['created']) if isinstance(p['created'], str) else p['created']
#         p['tags'] = get_post_tags(p['id'])
#     return posts

# %%
#| export
def get_posts(
        n: Union[int, None]=None, # number of posts to load
        tags: Union[List, None] = None, # list of tags
        logged_in: bool=False, # is user logged in
        offset: Union [int, None]=None # where to start to load posts once ordered
        )->list: # list of posts
    if tags:
        place_holders = ','.join('?' * len(tags))
        private_posts_query = '' if logged_in else 'AND p.private = False '
        query = f"""
            SELECT DISTINCT p.* FROM posts p
            JOIN post_tags pt ON p.id = pt.post_id
            JOIN tags t ON pt.tag_id = t.id
            WHERE t.name IN ({place_holders}) AND p.published = True {private_posts_query}
            ORDER BY p.created DESC
        """
        if n: query += f" LIMIT {n}"
        if offset: query += f" OFFSET {offset}"
        posts = state.pdb.q(query, tags)
    else:
        posts = list(state.posts_t.rows_where("published = ? AND (private = False OR ?)", [True, logged_in], 
            order_by="created DESC", limit=n, offset=offset))
        posts = [dict(r) for r in posts]

    for p in posts:
        p['created'] = datetime.fromisoformat(p['created']) if isinstance(p['created'], str) else p['created']
        p['tags'] = get_post_tags(p['id'])
    return posts

# %% [markdown]
# #| export
# Main post retrieval function. Optionally filters by tags and limits results. Returns dicts with parsed datetime and tag list attached.

# %%
#| export
def tag_pill(tag_name, selected_tags):
    if tag_name in selected_tags:
        new_tags = selected_tags - {tag_name}
        selected = True
    else:
        new_tags = selected_tags | {tag_name}
        selected = False
    link = f"/blog?tags={','.join(new_tags)}" if new_tags else "/blog"
    cls = [ButtonT.primary if selected else ButtonT.secondary, ButtonT.sm, "rounded-lg"]
    return Button(tag_name, cls=cls, hx_get=link, **hx_attrs("#posts-list"))

# %% [markdown]
# #| export
# Creates a clickable tag button. Clicking adds/removes the tag from the current filter. Selected tags are styled differently.

# %%
#| export
def tag_filter(selected):
    # Return a div containing all of the tags and their selection status. We also need a button to clear the current selection
    selected: set # a set containing the names of the selected tags
    tags = get_tags(state.tags_t)
    tag_pills = [tag_pill(tag_name, selected) for tag_name in tags]
    clear_btn = Button("X Clear", cls=[ButtonT.default, ButtonT.sm, "rounded-lg"], hx_get="/blog", **hx_attrs("#posts-list"))
    return Div(P("Filter: "), *tag_pills, clear_btn, cls="flex flex-wrap gap-2 items-center", id="tag-filter")

# %% [markdown]
# #| export
# Builds the tag filter bar: all tag pills plus a "Clear" button to reset filters.

# %%
#| export
def tag_badge(name):
    return Span(name, cls="text-xs px-2 py-1 rounded bg-muted")

# %%
#| export
def decode_tag_str(tag_str: str):
    # Decode a string containing a list of items with comma separation, needed to decode a list sent as a url parameter. 
    # Returns a set of unique items
    selected = {unquote(t.strip()) for t in (tag_str or '').split(',') if t.strip()}
    return selected

# %%
test_tags_decode_str = 'cycling, motorhome, coding'
decode_tag_str(test_tags_decode_str)
assert decode_tag_str(test_tags_decode_str) == {'cycling', 'motorhome', 'coding'}

# %% [markdown]
# #| export
# Small styled badge for displaying a tag name on post cards.b

# %%
#| export
def sentinal(
        n:int, # number of posts to load
        offset:int=None, # where to start the load
        tags: str=None # a list of active tags separated by commas
        )->Div: # Div to add to the end of the list of posts to act as a sentinal
    " Create a div to add to the end of the posts on the blog. When it becomes visible then it activates the load of more posts"
    get_str = f"/loadmore?offset={offset}&n={n}"
    if tags: 
        get_str += f"&tags={tags}"
    sentinal = Div(
        hx_get=get_str,    
        hx_trigger="intersect once",
        hx_swap="outerHTML",
        hx_target="this"
    )
    return sentinal

# %% [raw]
# @route
# def blog(htmx, req, tags:str=None):
#     logged_in = is_logged_in(req)
#     posts_to_load = 10
#     # selected is a SET of the name of the selected tags
#     selected = {unquote(t.strip()) for t in (tags or '').split(',') if t.strip()}
#     filtered = get_posts(n=posts_to_load, tags=selected, logged_in=logged_in)
#     tag_filter_div = tag_filter(selected)
#     items = [post_card(p, req) for p in filtered]
#     if len(items) == posts_to_load:
#         items.append(sentinal(offset=0, n=posts_to_load, tags=tags))
#
#     post_content = Div(*items, cls="space-y-2", id="posts-list") if items else P("No posts yet.", cls="text-muted-foreground", id="posts-list")
#     if htmx and htmx.target == "posts-list":
#         tag_filter_div.attrs['hx-swap-oob'] = 'true'
#         return post_content, tag_filter_div
#     return layout(req, H2("Blog"), tag_filter_div, Divider(cls=('my-2')), post_content, title="Blog", htmx=htmx)

# %%
#| export
@route
def blog(htmx, req, tags:str=None):
    logged_in = is_logged_in(req)
    posts_to_load = 10
    # selected is a SET of the name of the selected tags
    selected = decode_tag_str(tags)
    filtered = get_posts(n=posts_to_load, tags=selected, logged_in=logged_in)
    tag_filter_div = tag_filter(selected)
    items = [post_card(p, req) for p in filtered]
    if len(items) == posts_to_load:
        items.append(sentinal(offset=posts_to_load, n=posts_to_load, tags=tags))
    post_content = Div(*items, cls="space-y-2", id="posts-list") if items else P("No posts yet.", cls="text-muted-foreground", id="posts-list")
    if htmx and htmx.target == "posts-list":
        tag_filter_div.attrs['hx-swap-oob'] = 'true'
        return post_content, tag_filter_div
    return layout(req, H2("Blog"), tag_filter_div, Divider(cls=('my-2')), post_content, title="Blog", htmx=htmx)

# %%
#| export
@route("/loadmore")
def get_more_posts(req, n: int, offset: int, tags: str=None):
    logged_in = is_logged_in(req)
    selected_tags = decode_tag_str(tags)
    posts = get_posts(n=n, tags=selected_tags, logged_in=logged_in, offset=offset)
    items = [post_card(p, req) for p in posts]
    if len(items) == n:
        new_sentinal = sentinal(offset=offset+n, n=n, tags=tags)
        return (*items, new_sentinal)
    return (*items,)

# %% [markdown]
# I am inplementing an infinte scroll using a sentinal and the /loadmore route.  When I first load /blog it loads 10 posts and has the sentinal at the end with the following:
# <div hx-get="/loadmore?offset=10&amp;n=10&amp;tags=None" hx-trigger="intersect once" hx-swap="outerHTML" hx-target="this"></div>
# But when the sentinal is activated no more posts are loaded, when I know there should be more (13 in total)? Can you see why this might happen?

# %% [markdown]
# I have updated sentinal, does this look ok
# def sentinal(n:int, offset:int=None, tags: str=None):
#     # n: int posts to load
#     # offset: int where to load from
#     # tags: str string containing selected tags with comma separation
#     get_str = f"/loadmore?offset={offset}&n={n}"
#     if tags:
#         get_str += f"&tags={tags}"
#     sentinal = Div(
#         hx_get=get_str,
#         hx_trigger="intersect once",
#         hx_swap="outerHTML",
#         hx_target="this"
#     )
#     return sentinal

# %% [markdown]
# I guess I can check the tags passed in and if there are none, then not call the tags parameter so that it will default to None in the loadposts function.

# %% [markdown]
# In the htmx online guidebook they use a htmx trigger "revealled". Is this available in fastHTML and if so why use the intersect once.  The full code they have is:
# {% if contacts|length == 10 %}
#   <tr>
#     <td colspan="5" style="text-align: center">
#       <span hx-target="closest tr"
#         hx-trigger="revealed"
#         hx-swap="outerHTML"
#         hx-select="tbody > tr"
#         hx-get="/contacts?page={{ page + 1 }}">Loading More...</span>
#     </td>
#   </tr>
# {% endif %}

# %% [markdown]
# I am happy to use the intersect once, I just wanted to understand the difference.  Can you elaborate on the selection. I understand the filter they use just results in new rows being selected.  In your example you have a target of "this", what is that and how do you avoid getting headers etc?

# %% [markdown]
# Ok that makes sense and I think our approach is more efficient. Do I need to start by setting up pagination within get_posts, or should we create a new way to retrieve the pages?

# %% [markdown]
# Ok I have updated get_posts (I created a new version after the original)

# %% [markdown]
# given that the call to get_more_posts is to load more posts and that it uses outerHTML as a swop, I was returning additional posts and if necessary a new sentinal, what is the correct syntax for that?

# %% [markdown]
# I am confused by your third comment above, I am setting the sentinal offet so that it will load posts after the first load is complete, is that not correct?

# %% [markdown]
# I can see that when a call is made to /blog/more, ir is going to /blog/{slug}. how would you recomment i change the routes to avoid this. its a pain to change the route registration order, i guess i could just rename it to /load_more ir similar?

# %% [markdown]
# #| export
# Blog listing route. Parses tag filter from URL, fetches matching posts, renders tag filter + post cards. Uses HTMX OOB swap to update both filter and list on tag clicks.

# %%
#| export
def get_post_image(p):
    # check post content for image (/static/image/post_images/slug/*)
    # If image found then load a thumbnail of it
    img_ptn = r"!\[\[([^|\]]+?)(?:\|[^\]]+)?\]\]"
    imgs = re.findall(img_ptn,p["content"])
    img = imgs[0] if len(imgs)>0 else None
    if img:
        img_path = Path(img)
        slug = get_slug(p['title'])
        img_path = Path(config.POST_IMAGE_DIR) / Path(slug) / img_path
        return img_path
    else:
        return None

# %%
#| export
def check_if_admin(req):
    sess = req.scope.get('session', {})
    auth_username = sess.get('auth')
    user = state.auth.get_user(auth_username) if auth_username else None
    check_admin = is_admin = user and user.role == 'admin'
    return check_admin

# %% [markdown]
# #| export
# Extracts the first image path from a post's markdown content for use as a thumbnail.

# %%
#| export
def post_card(p, req):
    "Post summary card with optional admin controls"
    is_admin = check_if_admin(req)
    img_url = get_post_image(p)
    slug = p['slug']
    link_attrs = dict(href=f"/blog/{slug}", hx_get=f"/blog/{slug}", **hx_attrs())
    admin_btns = Div(
        A("Edit", href=f'/admin/edit/{slug}', cls="uk-btn uk-btn-default uk-btn-xs"),
        # Button("Delete", hx_post=f"/admin/delete/{p['slug']}", hx_confirm="Delete this post?", 
        #    cls=["uk-btn uk-btn-default uk-btn-xs"]),
        Button("Delete", hx_post=f"/admin/delete/{slug}", hx_confirm="Delete this post?", 
            hx_target="#main-content", hx_swap="innerHTML", 
            cls="uk-btn uk-btn-default uk-btn-xs"),
        A("Download", href=f"/admin/download/{p['slug']}", cls=[ButtonT.default, "uk-btn-xs"]),
        cls='flex gap-1'
    ) if is_admin else Div()
    return Div(cls="flex gap-4 p-3 -mx-3 rounded-lg border-b pb-4 hover:bg-muted/50 hover:shadow-lg transition-all")(
        Div(cls="flex-1")(
            A(H3(p['title']), P(p['excerpt'], cls="text-muted-foreground"), **link_attrs),
            Div(cls='flex justify-between items-center mt-2')(
                Div(Span(p['created'].strftime('%d %b %Y'), cls="text-sm text-muted-foreground mr-2"),
                    *[tag_badge(tag) for tag in p["tags"]], cls="flex items-center gap-2 flex-wrap"),
                admin_btns)),
        A(Img(src=img_url, cls="max-w-36 h-auto object-contain rounded"), **link_attrs) if img_url else None)

# %% [markdown]
# #| export
# Renders a post summary card with title, excerpt, date, tags, and optional thumbnail. Entire card is clickable via HTMX.

# %%
#| export
def add_post(title, content, excerpt="", tags=None, published=True, created=None, updated=None, slug: str=None, private: bool=False):
    if not slug:
        slug = get_slug(title)
    posts = state.pdb.t.posts
    tags_tbl = state.pdb.t.tags
    post_tags = state.pdb.t.post_tags
    now = datetime.now()
    post_id = slug_exists(slug)
    create_save_poster(content, slug)
    if post_id:
        post = posts.update(dict(id=post_id, title=title, slug=slug, content=content, excerpt=excerpt,
                                 created=created or now, updated=now, published=published, private=private))
        state.pdb.execute("DELETE FROM post_tags WHERE post_id = ?", [post_id])
    else:
        post = posts.insert(dict(title=title, slug=slug, content=content, excerpt=excerpt,
                                 created=created or now, updated=updated or now, published=published, private=private))
    post_id = post['id'] if isinstance(post, dict) else post.id
    if tags:
        if isinstance(tags, str): tags = [tags]
        for tag in tags:
            existing = list(tags_tbl.rows_where("name = ?", [tag], limit=1))
            if existing: tag_id = existing[0]['id']
            else:
                result = tags_tbl.insert(dict(name=tag))
                tag_id = result['id'] if isinstance(result, dict) else result.id
            if not list(post_tags.rows_where("post_id = ? AND tag_id = ?", [post_id, tag_id])):
                post_tags.insert(dict(post_id=post_id, tag_id=tag_id))
    return post_id

# %%
def post_exists(slug: str) -> bool:
    return bool(_state.posts_t(where='slug=?', vals=[slug]))

# %%
#| export
def process_upload(content: bytes, filename: str, slug:str=None, overwrite: bool=False):
    file_path = Path(filename)
    if file_path.suffix == '.md':
        try:
            md_text = content.decode('utf-8')
            post = frontmatter.loads(md_text)
            title = post.metadata['title']
            tags = post.metadata['tags']
            excerpt = post.metadata['excerpt']
            created = post.metadata.get('created')
            updated = post.metadata.get('updated')
            private = post.metadata.get('private', False)
            # Get the slug from the post if it exists, if not then create a slug
            slug = post.metadata.get('slug') or get_slug(title)
            if not overwrite and slug_exists(slug):
                return 'confirm', "Post already exists. Overwrite?", slug
            try:
                if overwrite:
                    add_post(slug=slug, title=title, content=post.content, excerpt=excerpt, tags=tags, created=created,
                    updated=updated, private=private)
                else:
                    add_post(title=title, content=post.content, excerpt=excerpt, tags=tags, created=created, updated=updated, private=private)
            except Exception as e:
                print(f'Error on save attempt: {e}')
                return False, f"Unable to save post: {e}", None
            return True, "Post saved", slug
        except Exception as e:
            return False, f"Error processing md: {type(e).__name__}: {e}", None
    elif file_path.suffix in ['.jpg', '.png', '.jpeg', '.tif', '.svg']:
        path_to_save = Path(config.POST_IMAGE_DIR) / Path(slug) / file_path.name
        path_to_save.parent.mkdir(parents=True, exist_ok=True)
        path_to_save.write_bytes(content)
        return True, f"File {path_to_save.name} saved", slug
    else:
        return False, f"Unknown file type {file_path.suffix}", slug

# %% [markdown]
# #| export
# Processes uploaded files. For `.md` files: parses frontmatter, rewrites image paths, saves to database. For images: saves to post-specific subfolder.

# %%
#| export
def create_poster_image(url, path_to_save):
    # Create a function to find instances of bunny.net video in the post and if they exist then create and save a thumbnail.  
    # The thumbnail will be saved in the folder static/posters/{slug}/{name}_poster.jpg
    try:
        out, _ = (
            ffmpeg.input(url, ss=0)
            .output(str(path_to_save), vframes=1, loglevel='error')
            .run(overwrite_output=True)
        )
        return True
    except Exception as e:
        print(f"Image processing exception: {e}")
        return False

# %%
def create_save_poster(content: NotStr, slug: str):
    # Extract all of the bunny.net embeddings {{bunny:filename}}
    # For each instance create the CDN URL
    # Create a thumbnail using the URL an ffmpeg
    # Save the thumbnail using the slug

    content = str(content)
    pattern = r'''
(<p[^>]*>)? # find and capture <p> if it is there.  Allows for intermediate characters after p but only up to >
(\s*)? # Optional spaces between the tag and the start of the embedded code
\{\{bunny:(?P<name>[A-Za-z0-9_]+)(?P<suffix>(\.mp4|\.webm))\}\} # catch the brackets, the name of the file and the suffix
(\s*)?(</p>)? # Optional space after the brackets before the termination of the p tag
'''

    def generate_save_poster(match):
        file_name = match['name']
        suffix = match['suffix']
        dir_full_path = config.POSTER_DIR / slug
        dir_full_path.mkdir(exist_ok=True)
        path_to_save = dir_full_path / Path(file_name+config.POSTER_SUFFIX+'.jpg')
        url = f"https://{config.CDN}/{file_name+suffix}"

        result = create_poster_image(url, path_to_save)
        if not result:
            print(f'error proessing poster: (file_name)')

    # find all occurences
    content = re.sub(pattern, generate_save_poster, content, flags=re.VERBOSE + re.MULTILINE)

# %%
#| export
def create_save_poster(content: NotStr, slug: str):
    content = str(content)
    pattern = r'''
    (<p[^>]*>)?
    (\s*)?
    \{\{bunny:(?P<path>[A-Za-z0-9_/-]*/)?(?P<name>[A-Za-z0-9_]+)(?P<suffix>(\.mp4|\.webm))\}\}
    (\s*)?
    (</p>)?
    '''

    def generate_save_poster(match):
        path = match['path'] or ''
        file_name = match['name']
        suffix = match['suffix']
        
        # Build unique poster filename: folder_path_filename_poster.jpg
        path_prefix = path.replace('/', '_') if path else ''
        poster_name = f"{path_prefix}{file_name}{config.POSTER_SUFFIX}.jpg"
        
        dir_full_path = config.POSTER_DIR / slug
        dir_full_path.mkdir(exist_ok=True)
        path_to_save = dir_full_path / poster_name
        
        url = f"https://{config.CDN}/{path}{file_name}{suffix}"

        result = create_poster_image(url, path_to_save)
        if not result:
            print(f'error processing poster: {file_name}')

    content = re.sub(pattern, generate_save_poster, content, flags=re.VERBOSE + re.MULTILINE)

# %%
#| export
@route('/admin/upload')
def get(htmx):
    # Create file upload form for the post
    return Div(Div(A('Cancel', href='/', cls=f"{ButtonT.secondary} px-4 py-2"), Upload("Upload Button!", id='upload1', multiple=True), cls='flex gap-2'),
               Div(id='upload-message'),
               Form(
                UploadZone(DivCentered(Span("Upload Zone"), UkIcon("upload")), id='upload2', accept=['.md', '.jpg', '.jpeg', 'png', 'svg', 'gif'], multiple=True,
                hx_target='#upload-message', hx_trigger='change', hx_post='/admin/upload', hx_swap='innerHTML', hx_encoding="multipart/form-data"),
                cls='space-y-4')
    )

# %%
#| export
def save_pending(slug: str, md_name: str, md_content: bytes, images: list[tuple[str, bytes]]):
    """Save md content and images to temp storage keyed by slug.
    images is a list of (filename, bytes) tuples."""
    import pickle
    Path(f'/tmp/pending_{slug}.pkl').write_bytes(pickle.dumps({'name': md_name, 'md': md_content, 'images': images}))

# %%
#| export
def load_pending(slug: str):
    """Returns (md_content, images) or None if not found."""
    import pickle
    p = Path(f'/tmp/pending_{slug}.pkl')
    if not p.exists(): return None
    data = pickle.loads(p.read_bytes())
    return data['name'], data['md'], data['images']

# %%
#| export
def clear_pending(slug: str):
    Path(f'/tmp/pending_{slug}.pkl').unlink(missing_ok=True)

# %%
@route('/admin/upload')    
def post(upload2: list[UploadFile]):
    files = [(f.filename, f.file.read()) for f in upload2]
    md_files = [(n, c) for n, c in files if n.endswith('.md')]
    img_files = [(n, c) for n, c in files if not n.endswith('.md')]
    results = []
    slug = None
    if img_files and len(md_files)==0:
        return Div(Alert("Please upload a post (.md file) with images, or upload images separately", cls=AlertT.warning))
    for name, content in md_files:
        success, message, slug = process_upload(content, name)
        results.append((name, success, message))
    for name, content in img_files:
        success, message, _ = process_upload(content, name, slug=slug)
        results.append((name, success, message))
    header = ["Name", 'Success', 'Message']
    body = [[r[0], r[1], r[2]] for r in results]
    return Div(H2("Post upload results"), TableFromLists(header, body))

# %%
#| export
def do_upload(md_files, img_files, slug: str=None, overwrite: bool=False):
    results = []
    for name, content in md_files:
        success, message, slug_from_title = process_upload(content, name, overwrite=overwrite)
        if not slug:
            slug = slug_from_title
        if success == 'confirm':
            save_pending(slug, name, content, img_files)
            return 'confirm', slug
        results.append((name, success, message))
    for name, content in img_files:
        success, message, _ = process_upload(content, name, slug=slug)
        results.append((name, success, message))
    header = ["Name", "Success", "Message"]
    return 'done', TableFromLists(header, [[r[0], r[1], r[2]] for r in results])

# %%
#| export
@route('/admin/upload')
def post(upload2: list[UploadFile]):
    files = [(f.filename, f.file.read()) for f in upload2]
    md_files = [(n, c) for n, c in files if n.endswith('.md')]
    img_files = [(n, c) for n, c in files if not n.endswith('.md')]
    status, result = do_upload(md_files, img_files)
    if status == 'confirm':
        slug = result
        # return a confirmation dialog - result is the slug
        return Div(P("Post already exists. Overwrite?"),
                   Button("Yes, overwrite", hx_post=f"/admin/upload/overwrite?slug={slug}", hx_target="#upload-message", hx_swap="innerHTML"),
                   Button("Cancel", cls=ButtonT.secondary, hx_get="/admin/upload", hx_target="#upload-message", hx_swap="innerHTML"))
    return Div(H2("Upload results"), result)

# %%
#| export
@route('/admin/upload/overwrite')
def post(slug: str):
    pending = load_pending(slug)
    if not pending: return Alert("No pending upload found", cls=AlertT.warning)
    md_name, md_content, img_files = pending
    status, result = do_upload([(md_name, md_content)], img_files, slug=slug, overwrite=True)
    clear_pending(slug)
    return Div(H2("Upload results"), result)

# %% [markdown]
# ###### end-section

# %% [markdown]
# I don't think this is correct as the filename of the md file is not necessarily going to be slug + '.md'. The filename surely needs to come from the originally supplied name? I think that this flaw is built into the load and save pending functions as well. Do you agree or have I misunderstood?

# %% [markdown]
# #| export
# Admin upload handler (POST): processes markdown files first (to get slug), then images. Returns a results table showing success/failure for each file.

# %%
#| export
def rewrite_image_paths(content: str, slug: str) -> str:
    # img_ptn = r"!\[.*?\]\((/static/image/post_images/[^)]+)\)"
    img_ptn = r"(!\[.*?\])\(([^/)]+\.(jpg|jpeg|png|gif|svg))\)"
    replacement = rf"\1(/static/image/post_images/{slug}/\2)"
    return re.sub(img_ptn, replacement, content, flags=re.IGNORECASE)

# %% [markdown]
# #| export
# Rewrites simple image filenames like `![](image.jpg)` to full paths like `![](/static/image/post_images/{slug}/image.jpg)`. Called at upload time.

# %%
#| export
def convert_obsidian_images(content: str, image_base: str = "/static/image/about") -> str:
    """Convert Obsidian ![[image.ext]] syntax to standard markdown ![](/path/image.ext)"""
    # pattern = r'!\[\[([^\]]+\.(jpg|jpeg|png|gif|svg))\]\]'
    pattern = r'!\[\[([^|\]\n]+\.(?:jpg|jpeg|png|gif|svg))(?:[\\|][^\]]+)?\]\]'
    replacement = rf'![]({image_base}/\1)'
    return re.sub(pattern, replacement, content, flags=re.IGNORECASE)

def load_md_file(path: str, image_base: str = None) -> str:
    """Load markdown file, optionally converting Obsidian image syntax"""
    content = Path(path).read_text()
    if image_base:
        content = convert_obsidian_images(content, image_base)
    return content

# %%
test_img_1_content = '''test string with obscidian markdown, first without a table:
![[IMG_3932.jpeg]]
next with size:
![[IMG_3932.jpeg|250]]
and with size and position:
![[IMG_3932.jpeg|250|right]]
Then some rubbish
'''
base_path = "/static/image/post_images/post_1"
converted = convert_obsidian_images(test_img_1_content, base_path)
converted
# Out:
# 'test string with obscidian markdown, first without a table:\n![](/static/image/post_images/post_1/IMG_3932.jpeg)\nnext with size:\n![](/static/image/post_images/post_1/IMG_3932.jpeg)\nand with size and position:\n![](/static/image/post_images/post_1/IMG_3932.jpeg)\nThen some rubbish\n'

# %% [markdown]
# #| export
# `convert_obsidian_images` converts Obsidian's `![[image.ext]]` syntax to standard markdown. `load_md_file` loads a markdown file and optionally converts image syntax.

# %%
#| export
def about_content():
    md = load_md_file(config.STATIC_DIR / "content/About.md", image_base="/static/image/about")
    return render_md(md)

# %% [markdown]
# #| export
# Loads and renders the About page from a markdown file, converting Obsidian image syntax to proper paths.

# %%
#| export
@route
def about(req, htmx):
    return layout(req, about_content(),title="About Me", htmx=htmx)

# %% [markdown]
# #| export
# Route to display the About page.

# %% [markdown]
# #| export
# #### Develop Markdown Renderer
# Note - for now strava, images and youtube embeddings will be handled by separate functions after page rendering.  At a later data this can be integrated into the EnhancedRenderer class once appropriate tokens are defined for each

# %%
#| export
from mistletoe import Document
from monsterui.franken import FrankenRenderer

# %%
#| export
class EnhancedRenderer(FrankenRenderer):
    def _is_external(self, url):
        return url.startswith(('http://', 'https://', '//'))

    def render_link(self, token):
        target = self.escape_url(token.target)      
        title = f' title="{self.escape_html(token.title)}"' if token.title else ''
        inner = self.render_inner(token)

        # Determine if we need the new tab attributes
        extra_attrs = ' target="_blank" rel="noopener noreferrer"' if self._is_external(target) else ''

        return f'<a href="{target}"{extra_attrs}{title}>{inner}</a>'

    def render_autolink(self, token):
        target = self.escape_url(token.target)
        inner = self.render_inner(token)
        
        # Autolinks are almost always external, but we'll check anyway
        extra_attrs = ' target="_blank" rel="noopener noreferrer"' if self._is_external(target) else ''
        
        return f'<a href="{target}"{extra_attrs}>{inner}</a>'

    def render_paragraph(self, token):
        if self._suppress_ptag_stack[-1]: return self.render_inner(token)
        return f'<p class="text-lg leading-relaxed mb-6">{self.render_inner(token)}</p>'

# %% [markdown]
# #| export
# #### Develop Strava iFrame embedding
# In your markdown, use:
# `{{strava:12345678}}`
# This will be replaced with an embedded Strava activity

# %%
#| export
def strava_embed(activity_id: str):
    return Div(cls="strava-embed-placeholder", data_embed_type="activity", data_embed_id=activity_id, data_style="standard")

# %% [markdown]
# #| export
# Returns a Strava embed div with the given activity ID. The Strava embed.js script (loaded in headers) will transform this into a full embed.

# %%
#| export
def process_strava_embeddings(page: NotStr):
    page = str(page)
    # Pattern to match {{strava:ID}} possibly wrapped in <p> tags
    pattern_placeholder = r'(<p[^>]*>)?\s*\{\{strava:(\d+)\}\}\s*(</p>)?'
    
    def replace_strava(match):
        activity_id = match.group(2)
        return to_xml(strava_embed(activity_id))
    
    page = re.sub(pattern_placeholder, replace_strava, page)
    return NotStr(page)

# %% [markdown]
# #| export
# Post-processes rendered HTML to find `{{strava:ID}}` placeholders and replace them with actual Strava embed divs.

# %% [markdown]
# #### Develop Komoot embeddings
# Komoot does not force users to login to see the iframe and so I will use Komoot wherever possible

# %% [markdown]
# #| export
# #### Process Image Embeddings from Obscidian
# we can set image size, and justification within Obscidan using the nomenclature:
#
# ![['image_name'|'size(w)'|'size(h)'|'justification']]
#
# where justification is optional and can be 'left'|'center'|'right'
# and size(w) and size(h) are optional (if only one is provided it will apply to the width)
#
# Obsidian image syntax examples:
# ```
# ![[image.jpg|300]]           - width 300px
# ![[image.jpg|300|right]]     - float right, text wraps
# ![[image.jpg|300x200|center]] - fixed size, centered
# ```

# %% [raw]
# Gallery layout
# <iframe src="https://www.komoot.com/tour/2894225074/embed?share_token=a0odP3j5E5ZttSC0QLn2DM6JarX4rBSm4LRJ4eKeqKMVu6OGoX&amp;layout=gallery&amp;gallery=1" width="100%" height="640" frameborder="0" scrolling="no"></iframe>
#
# Classic layout
# <iframe src="https://www.komoot.com/tour/2894225074/embed?share_token=a0odP3j5E5ZttSC0QLn2DM6JarX4rBSm4LRJ4eKeqKMVu6OGoX&amp;layout=classic&amp;profile=1" width="100%" height="700" frameborder="0" scrolling="no"></iframe>

# %%
#| export
def process_komoot_embed(page: NotStr):
    page = str(page)
    pattern = r'(<p[^>]*>)?\s*\{\{komoot:(\d+)\|([A-Za-z0-9]+)(?:\|(gallery|classic))?\}\}\s*(</p>)?'
    
    def replace_komoot(match):
        tour_id = match.group(2)
        share_token = match.group(3)
        layout = match.group(4) or 'classic'
        if layout == 'gallery':
            src = f"https://www.komoot.com/tour/{tour_id}/embed?share_token={share_token}&layout=gallery&gallery=1"
            height = "640"
        else:
            src = f"https://www.komoot.com/tour/{tour_id}/embed?share_token={share_token}&layout=classic&profile=1"
            height = "700"
        return f'<iframe src="{src}" width="100%" height="{height}" frameborder="0" scrolling="no"></iframe>'
    
    page = re.sub(pattern, replace_komoot, page)
    return NotStr(page)

# %% [markdown]
# #### Process Obscidian Images

# %% [raw]
# def process_obsidian_images(page: NotStr, image_base: str) -> NotStr:
#     page = str(page)
#     pattern = new3 = r'''!\[\[(?P[^\]]+\.(jpg|jpeg|png|gif|svg)) # Image part, must be present
# (?:\|(?P<size1>\d+))? # First size dimension (with leading pipe symbol (optional)
# (?:x(?P<size2>\d+))? # Second size dimension (with leading x)
# (?:\|(?P<location>left|right|center))?
# \]\] # End of image (must be present)
# '''
#
#     for match in re.finditer(pattern, page, re.MULTILINE + re.VERBOSE):
#         m = match.groupdict()
#
#         # 1. Build src path
#         src = f"{image_base}/{m['image']}"
#
#         # 2. Build style string from size1, size2, location
#         styles = []
#         if m['size1']:
#             styles.append(f"width: {m['size1']}px")
#         if m['size2']:
#             styles.append(f"height: {m['size2']}px")
#         if m['location'] == 'center':
#             styles.append("display: block; margin: auto")
#         elif m['location'] == 'right':
#             styles.append("float: right; margin-left: 1rem")
#         elif m['location'] == 'left':
#             styles.append("float: left; margin-right: 1rem")
#
#         style_str = "; ".join(styles)
#
#         # 3. Build img tag and replace
#         img_tag = f'<img src="{src}" style="{style_str}">'
#         page = page.replace(match.group(0), img_tag)
#
#     return NotStr(page)

# %% [markdown]
# i would like to be able to add css classes to manage grid layout od images on the page. when i do that though it doesnt work with the obscidian image formats we have been using (the img src path etc doesnt work). can you suggest a clean way to enable this

# %% [markdown]
# We could use a wrapper as you suggest but I am concerend as to how many add-ons we are applying to the markdown renderer, and especially when they all operate sequentially, at some point we might get interference issues.  Is there a way to adapt the process obscidian image function to detect generate img sources that would work whilst embedded in the css or html?

# %% [raw]
# #| export
# def _process_standalone_images(content: str, image_base: str) -> str:
#     """Process remaining ![[image]] without captions into <img> tags"""
#     # Same as your current process_obsidian_images but for markdown (not HTML)
#     pattern = r'''
#         !\[\[(?P[^\]\n]+\.(?:jpg|jpeg|png|gif|svg))
#         (?:\|(?P<size1>\d+))?
#         (?:x(?P<size2>\d+))?
#         (?:\|(?P<location>left|right|center))?
#         \]\]
#         (?!\n>)  # Negative lookahead: not followed by newline + >
#     '''
#
#     def make_image(match):
#         m = match.groupdict()
#         src = f"{image_base}/{m['image']}"
#
#         styles = []
#         if m['size1']:
#             styles.append(f"width: {m['size1']}px")
#         if m['size2']:
#             styles.append(f"height: {m['size2']}px")
#         if m['location'] == 'center':
#             styles.append("display: block; margin: auto")
#         elif m['location'] == 'right':
#             styles.append("float: right; margin-left: 1rem")
#         elif m['location'] == 'left':
#             styles.append("float: left; margin-right: 1rem")
#
#         style_str = "; ".join(styles)
#         return f'<img src="{src}" style="{style_str}">' if styles else f'<img src="{src}">'
#
#     return re.sub(pattern, make_image, content, flags=re.MULTILINE + re.VERBOSE)

# %% [raw]
# #| export
#  def _process_figures(content: str, image_base: str) -> str:
#     """Process ![[image]] followed by > caption into <figure> elements"""
#     pattern = r'''
#         !\[\[(?P[^\]\n]+\.(?:jpg|jpeg|png|gif|svg)) # Image filename
#         (?:\|(?P<size1>\d+))?                             # Optional width
#         (?:x(?P<size2>\d+))?                               # Optional height
#         (?:\|(?P<location>left|right|center))?            # Optional location
#         \]\]                                               # Close brackets
#         \n>\s*(?P<caption>[^\n]+)                          # Newline then > caption
#     '''
#
#     def make_figure(match):
#         m = match.groupdict()
#         src = f"{image_base}/{m['image']}"
#
#         # Build styles
#         styles = []
#         if m['size1']:
#             styles.append(f"width: {m['size1']}px")
#         if m['size2']:
#             styles.append(f"height: {m['size2']}px")
#
#         style_str = "; ".join(styles)
#         style_attr = f' style="{style_str}"' if styles else ''
#
#         caption = m['caption'].strip()
#         return f'<figure>\n<img src="{src}"{style_attr}>\n<figcaption style="font-size:0.85em; color:#666; text-align:center;">{caption}</figcaption>\n</figure>'
#
#     return re.sub(pattern, make_figure, content, flags=re.MULTILINE + re.VERBOSE)

# %% [raw]
# def process_gallery(content: str) -> str:
#     """Find {{gallery:N}}...{{/gallery}} blocks and wrap contents in a grid div."""
#     pattern = r'\{\{gallery:(\d+)\}\}(.*?)\{\{/gallery\}\}'
#
#     def make_gallery(match):
#         cols = match.group(1)
#         inner = match.group(2).strip()
#         return f'<div class="grid grid-cols-{cols} gap-4">\n{inner}\n</div>'
#
#     return re.sub(pattern, make_gallery, content, flags=re.DOTALL)

# %% [markdown]
# Its not catching img2 at all and the justification for img1 is incorrect

# %% [markdown]
# I think actually that its ok to miss the second image as that isn't a figure and so should be handled by the _process_standalone_images function.  Could you adapt _process_figures to cope with the optional location, and size, or alternatively create a single function that combines dealing with the figures, captions, size and locations if that would be cleaner and avoid the issues with inconsistency between the different functions

# %% [markdown]
# I am in a bit of a rush so please make the changes

# %% [raw]
# def process_obsidian_images(content: str, image_base: str) -> str:
#     pattern = r'''
#         !\[\[(?P[^\]\n]+\.(?:jpg|jpeg|png|gif|svg))
#         (?:\|(?P<size1>\d+))?
#         (?:x(?P<size2>\d+))?
#         (?:\|(?P<location>left|right|center))?
#         \]\]
#         (?:\n>\s*(?P<caption>[^\n]+))?
#     '''
#
#     def make_element(match):
#         m = match.groupdict()
#         src = f"{image_base}/{m['image']}"
#         loc = m.get('location')
#
#         img_styles = []
#         if m['size1']: img_styles.append(f"width: {m['size1']}px")
#         if m['size2']: img_styles.append(f"height: {m['size2']}px")
#
#         wrap_styles = []
#         if loc == 'right':    wrap_styles = ['float: right', 'margin-left: 1rem']
#         elif loc == 'left':   wrap_styles = ['float: left', 'margin-right: 1rem']
#         elif loc == 'center': wrap_styles = ['display: block', 'margin: auto']
#
#         # elif loc == 'center': wrap_styles = ['display: block', 'margin: auto', 'text-align: center']
#
#         caption = m.get('caption')
#         if caption:
#             wrap_style = f' style="{"; ".join(wrap_styles)}"' if wrap_styles else ''
#             img_style = f' style="{"; ".join(img_styles)}"' if img_styles else ''
#             return (f'<figure{wrap_style}>\n'
#                     f'<img src="{src}"{img_style}>\n'
#                     f'<figcaption style="font-size:0.85em; color:#666; text-align:center">{caption.strip()}</figcaption>\n'
#                     f'</figure>')
#
#         all_styles = img_styles + wrap_styles
#         style = f' style="{"; ".join(all_styles)}"' if all_styles else ''
#         return f'<img src="{src}"{style}>'
#
#     return re.sub(pattern, make_element, content, flags=re.MULTILINE + re.VERBOSE)

# %%
#| export
def process_gallery(content: str) -> str:
    """Find {{gallery:N}}...{{/gallery}} blocks, strip size/location hints, and wrap in grid div."""
    strip_hints = re.compile(
        r'(!\[\[[^\]\n]+\.(?:jpg|jpeg|png|gif|svg))(?:\|\d+)?(?:x\d+)?(?:\|(?:left|right|center))?\]\]',
        re.IGNORECASE
    )
    pattern = r'\{\{gallery:(\d+)\}\}(.*?)\{\{/gallery\}\}'

    def make_gallery(match):
        cols = match.group(1)
        inner = strip_hints.sub(lambda m: m.group(1) + ']]', match.group(2).strip())
        return f'<div class="grid grid-cols-{cols} gap-4">\n{inner}\n</div>'

    return re.sub(pattern, make_gallery, content, flags=re.DOTALL)

# %%
#| export
def process_obsidian_images(content: str, image_base: str) -> str:
    pattern = r'''
        !\[\[(?P[^\]\n]+\.(?:jpg|jpeg|png|gif|svg))
        (?:\|(?P<size1>\d+))?
        (?:x(?P<size2>\d+))?
        (?:\|(?P<location>left|right|center))?
        \]\]
        (?:\n>\s*(?P<caption>[^\n]+))?
    '''

    def make_element(match):
        m = match.groupdict()
        src = f"{image_base}/{m['image']}"
        loc = m.get('location')

        img_styles = []
        if m['size1']: img_styles.append(f"width: {m['size1']}px")
        if m['size2']: img_styles.append(f"height: {m['size2']}px")

        wrap_styles = []
        if loc == 'right':    wrap_styles = ['float: right', 'margin-left: 1rem']
        elif loc == 'left':   wrap_styles = ['float: left', 'margin-right: 1rem']
        elif loc == 'center': wrap_styles = ['display: block', 'margin: auto']

        # elif loc == 'center': wrap_styles = ['display: block', 'margin: auto', 'text-align: center']

        caption = m.get('caption')
        if caption:
            fig_style = "; ".join(wrap_styles) if wrap_styles else None
            img_tag = Img(src=src, style="; ".join(img_styles)) if img_styles else Img(src=src)
            return str(Figure(style=fig_style)(
                A(img_tag, href=src, data_type="image"),
                Figcaption(caption.strip(), style="font-size:0.85em; color:#666; text-align:center")
            ))

        all_styles = img_styles + wrap_styles
        img_tag = Img(src=src, style="; ".join(all_styles)) if all_styles else Img(src=src)
        return str(A(img_tag, href=src, data_type="image"))

    return re.sub(pattern, make_element, content, flags=re.MULTILINE + re.VERBOSE)

# %%
#| export
def preprocess_markdown(content: str, image_base: str) -> str:
    content = process_gallery(content)
    content = process_obsidian_images(content, image_base)
    return content

# %%
# --- Test 1: Single images ---
test_md_images = '''Some text before.

![[IMG_3932.jpeg]]

![[IMG_3932.jpeg|250]]

![[IMG_3932.jpeg|250|right]]

Text after.
'''

expected_images = '''Some text before.

<img src="/static/image/post_images/post_1/IMG_3932.jpeg">

<img src="/static/image/post_images/post_1/IMG_3932.jpeg" style="width: 250px">

<img src="/static/image/post_images/post_1/IMG_3932.jpeg" style="width: 250px; float: right; margin-left: 1rem">

Text after.
'''


# --- Test 2: Gallery wrapper ---
test_md_gallery = '''Some intro text.

{{gallery:2}}
![[img1.jpg|300]]
![[img2.jpg|300]]
{{/gallery}}

Closing text.
'''

expected_gallery = '''Some intro text.

<div class="grid grid-cols-2 gap-4">
<img src="/static/image/post_images/post_1/img1.jpg">
<img src="/static/image/post_images/post_1/img2.jpg">
</div>

Closing text.
'''

# --- Test 3: Mixed imaged ---
test_md_mixed_images = '''Intro text.

![[img1.jpg|250|left]]
> A caption for the first image

![[img2.jpg|300]]

![[img3.jpg|400|center]]
> Another caption here

Closing text.
'''

expected_mixed = '''Intro text.

<figure style="float: left; margin-right: 1rem">
<img src="/static/image/post_images/post_1/img1.jpg" style="width: 250px">
<figcaption style="font-size:0.85em; color:#666; text-align:center">A caption for the first image</figcaption>
</figure>

<img src="/static/image/post_images/post_1/img2.jpg" style="width: 300px">

<figure style="display: block; margin: auto">
<img src="/static/image/post_images/post_1/img3.jpg" style="width: 400px">
<figcaption style="font-size:0.85em; color:#666; text-align:center">Another caption here</figcaption>
</figure>

Closing text.
'''

# %%
# Test 1. check basic images are processed
result = preprocess_markdown(test_md_images, image_base="/static/image/post_images/post_1")
assert result == expected_images
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[74], line 3
#       1 # Test 1. check basic images are processed
#       2 result = preprocess_markdown(test_md_images, image_base="/static/image/post_images/post_1")
# ----> 3 assert result == expected_images
#
# AssertionError:

# %%
# Test 2
result = preprocess_markdown(test_md_gallery, image_base="/static/image/post_images/post_1")
assert result == expected_gallery
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[75], line 3
#       1 # Test 2
#       2 result = preprocess_markdown(test_md_gallery, image_base="/static/image/post_images/post_1")
# ----> 3 assert result == expected_gallery
#
# AssertionError:

# %%
# Test 3
result = preprocess_markdown(test_md_mixed_images, image_base="/static/image/post_images/post_1")
assert result == expected_mixed
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[76], line 3
#       1 # Test 3
#       2 result = preprocess_markdown(test_md_mixed_images, image_base="/static/image/post_images/post_1")
# ----> 3 assert result == expected_mixed
#
# AssertionError:

# %%
test_cannock = '''
Some random words

{{gallery:2}}
![[vlcsnap-5.png]]
>There was quite l lot of standing water! 
![[vlcsnap-6.png]]
>Lovely views with the sun breaking through
{{/gallery}}

More random words
'''

# %%
result = preprocess_markdown(test_cannock, image_base="/static/image/post_images/post_1")

# %%
result
# Out:
# '\nSome random words\n\n<div class="grid grid-cols-2 gap-4">\n<figure class="p-4 my-4 border border-gray-200 dark:border-gray-800 rounded-lg shadow-sm bg-card "><a href="/static/image/post_images/post_1/vlcsnap-5.png" data-type="image"><img src="/static/image/post_images/post_1/vlcsnap-5.png"></a><figcaption style="font-size:0.85em; color:#666; text-align:center">There was quite l lot of standing water!</figcaption></figure>\n<figure class="p-4 my-4 border border-gray-200 dark:border-gray-800 rounded-lg shadow-sm bg-card "><a href="/static/image/post_images/post_1/vlcsnap-6.png" data-type="image"><img src="/static/image/post_images/post_1/vlcsnap-6.png"></a><figcaption style="font-size:0.85em; color:#666; text-align:center">Lovely views with the sun breaking through</figcaption></figure>\n</div>\n\nMore random words\n'

# %% [markdown]
# The preprocess_markdown function is not working properly for a gallery with two images and captions.  I created a test case test_cannock and you can see the output above.  The rendered post looks like:
#
# ![image.png](attachment:99554fe7-95d5-4800-bbe6-570a3acd1e85)
#
# Can you see what is not working and suggest a solution

# %% [markdown]
# Lets explore it with a new function to preprocess the markdown and see how it works. I think that if we do it in this was the process_obscidian_image and other functions won't do anything and could eventually be removed, but short term I could just add this pre-processing function to the blogpost load

# %% [raw]
# # --- Test 1: Single images ---
# test_md_images = '''Some text before.
#
# ![[IMG_3932.jpeg]]
#
# ![[IMG_3932.jpeg|250]]
#
# ![[IMG_3932.jpeg|250|right]]
#
# Text after.
# '''
#
# expected_images = '''Some text before.
#
# <img src="/static/image/post_images/post_1/IMG_3932.jpeg">
#
# <img src="/static/image/post_images/post_1/IMG_3932.jpeg" style="width: 250px">
#
# <img src="/static/image/post_images/post_1/IMG_3932.jpeg" style="width: 250px; float: right; margin-left: 1rem">
#
# Text after.
# '''
#
#
# # --- Test 2: Gallery wrapper ---
# test_md_gallery = '''Some intro text.
#
# {{gallery:2}}
# ![[img1.jpg|300]]
# ![[img2.jpg|300]]
# {{/gallery}}
#
# Closing text.
# '''
#
# expected_gallery = '''Some intro text.
#
# <div class="grid grid-cols-2 gap-4">
# <img src="/static/image/post_images/post_1/img1.jpg">
# <img src="/static/image/post_images/post_1/img2.jpg">
# </div>
#
# Closing text.
# '''
#
# # --- Test 3: Mixed imaged ---
# test_md_mixed_images = '''Intro text.
#
# ![[img1.jpg|250|left]]
# > A caption for the first image
#
# ![[img2.jpg|300]]
#
# ![[img3.jpg|400|center]]
# > Another caption here
#
# Closing text.
# '''
#
# expected_mixed = '''Intro text.
#
# <figure style="float: left; margin-right: 1rem">
# <img src="/static/image/post_images/post_1/img1.jpg" style="width: 250px">
# <figcaption style="font-size:0.85em; color:#666; text-align:center">A caption for the first image</figcaption>
# </figure>
#
# <img src="/static/image/post_images/post_1/img2.jpg" style="width: 300px">
#
# <figure style="display: block; margin: auto">
# <img src="/static/image/post_images/post_1/img3.jpg" style="width: 400px">
# <figcaption style="font-size:0.85em; color:#666; text-align:center">Another caption here</figcaption>
# </figure>
#
# Closing text.
# '''

# %% [markdown]
# #### Process youtube embedding

# %% [markdown]
# #| export
# #### Develop iframe approach for youtube material
# Note that the you tube link must be on a separate line (in Obscidian this means a blank line above and below to force a `<p>, </p>` pair of tags)
# At present adding youtube playlists or time stamps is not supported

# %% [markdown]
# I would prefer option A (but as we said with the folder being optional

# %% [raw]
# def process_gallery(content: NotStr):
#
#     pattern = r'''\{\{gallery: # Find opening gallery
#         (?P<gallery_type>\d+?)\}\} # Non greedy find the gallery descriptor
#         (?P<img_text>.*?) # Find intermediate text before the end gallery tag (could be ![[]] or html so leave as is
#         \{\{/gallery\}\} # Find gallery closing tag
# '''
#     def make_gallery_str(match):
#         if str(match['gallery_type']) == '2':
#             html_to_use = '<div class="grid grid-cols-2 gap-4">\n'
#         elif match['gallery_type'] == '3':
#             html_to_use = '<div class="grid grid-cols-3 gap-4">\n'
#         else:
#             return match[0] # Don't know what to do so return the entire match to leave it the same
#
#         # Assemble rest of string
#         inner = match['img_text'].strip('\n') # Remove any line feeds captured by the regex
#         new_str = html_to_use + inner + '\n</div>'
#         return new_str
#
#     content = re.sub(pattern, make_gallery_str, content, flags=re.MULTILINE+re.VERBOSE+re.DOTALL)
#
#     return NotStr(content)

# %% [raw]
# def preprocess_markdown(content: str, image_base: str):
#     # Process the raw image embeddings to generate img tags
#     content = NotStr(content)
#     content = str(process_obsidian_images(content, image_base))
#     # Now add the gallery
#     content = str(process_gallery(content))
#     return content

# %% [markdown]
# Great that is working.  I would like to be able to add a caption such as <figcaption style="font-size:0.85em; color:#666;">Your caption here</figcaption> </figure> but I guess I could add that in the markdown below the ![[image]] and it would pass through the renderer ok, if that is hte case I can set the caption as a template in obscidian

# %% [markdown]
# Option 2 seems more aligned with the way I am working at present but I wonder if I should add a tag to indicate it is a caption?

# %% [markdown]
# If I am using a gallery with a caption per image then

# %%
expected_gallery
# Out:
# 'Some intro text.\n\n<div class="grid grid-cols-2 gap-4">\n<img src="/static/image/post_images/post_1/img1.jpg">\n<img src="/static/image/post_images/post_1/img2.jpg">\n</div>\n\nClosing text.\n'

# %%
test_page = '''
This is a test page with a youtube embeddings
It is:

https://youtu.be/92xb0kbj2OM

Lets see if we can find them
'''

# %% [markdown]
# The gallery regex pattern is not working, can you see why

# %%
content = render_md(test_page, renderer=EnhancedRenderer)
content
# Out:
# '<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6">This is a test page with a youtube embeddings\nIt is:</p>\n<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6"><a href="https://youtu.be/92xb0kbj2OM" class="uk-link text-primary hover:text-primary-focus underline">https://youtu.be/92xb0kbj2OM</a></p>\n<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6">Lets see if we can find them</p>\n'

# %%
pattern_vb  = r'''
(<p[^>]*?>)? # find and capture <p> if it is there.  Allows for intermediate characters after p but only up to >
(\s*)?(<a[^>]*?>) # Find the <a and any href and class values up to the first >.  Optional
https?://(?:www\.)?(?:youtu\.be/|youtube\.com/watch\?v=)(?P<index>[A-Za-z0-9_-]{11}) # Catch the index of the youtube video
(</a>)? # Catch the terminating a tag if it exists
(</p>)? # Catch the terminating p tag if it exists
'''

# %%
for match in re.finditer(pattern_vb, str(content), re.MULTILINE + re.VERBOSE):
    print(match)
# Out:
# <re.Match object; span=(126, 334), match='<p class="text-lg leading-relaxed mb-6 text-lg le>

# %%
match[0], match['index']
# Out:
# ('<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6"><a href="https://youtu.be/92xb0kbj2OM" class="uk-link text-primary hover:text-primary-focus underline">https://youtu.be/92xb0kbj2OM</a></p>',
#  '92xb0kbj2OM')

# %%
match[1]
# Out:
# '<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6">'

# %%
video_id = match['index']
video_id
# Out:
# '92xb0kbj2OM'

# %%
iframe = Iframe(src=f"https://www.youtube.com/embed/{video_id}", title="YouTube video player", frameborder="0",
                            allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share",
                            referrerpolicy="strict-origin-when-cross-origin", allowfullscreen=True, cls="w-full aspect-video rounded-lg my-6")
iframe
# Out:
# <iframe src="https://www.youtube.com/embed/92xb0kbj2OM" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen class="w-full aspect-video rounded-lg my-6" title="YouTube video player"></iframe>

# %%
#| export
def process_you_tube_embed(page: NotStr):
        page = str(page)
        pattern_vb  = r'''
(<p[^>]*?>)? # find and capture <p> if it is there.  Allows for intermediate characters after p but only up to >
(\s*)?(<a[^>]*?>) # Find the <a and any href and class values up to the first >.  Optional
https?://(?:www\.)?(?:youtu\.be/|youtube\.com/watch\?v=)(?P<index>[A-Za-z0-9_-]{11}) # Catch the index of the youtube video
(</a>)? # Catch the terminating a tag if it exists
(</p>)? # Catch the terminating p tag if it exists
'''
        for match in re.finditer(pattern_vb, page, re.MULTILINE+re.VERBOSE):
            video_id = match['index']
            placeholder = Div(
                Img(src=f"https://img.youtube.com/vi/{video_id}/hqdefault.jpg",
                        cls="w-full aspect-video rounded-lg my-6"),
                cls="relative cursor-pointer",
                onclick="loadYouTube(this)",
                data_video_id=video_id  # becomes data-video-id in the HTML
                )
            placeholder = to_xml(placeholder)
            page = page.replace(match.group(0), placeholder)
        return NotStr(page)

# %%
new_content = process_you_tube_embed(content)
new_content
# Out:
# '<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6">This is a test page with a youtube embeddings\nIt is:</p>\n<div onclick="loadYouTube(this)" data-video-id="92xb0kbj2OM" class="relative cursor-pointer">\n<img src="https://img.youtube.com/vi/92xb0kbj2OM/hqdefault.jpg" class="w-full aspect-video rounded-lg my-6"></div>\n\n<p class="text-lg leading-relaxed mb-6 text-lg leading-relaxed mb-6">Lets see if we can find them</p>\n'

# %% [markdown]
# I added the above to a blog post. On the page it was rendered as {{embed:https://www.youtube.com/embed/92xb0kbj2OM?autoplay=0}} with the middle section as a hyperlink, which when I clicked it opened a player but completely replaced the existing page, I think the rendering has not worked properly

# %% [markdown]
# ```python
# No we tried that before we started to use the click to play.  I also tried the same in the test_embeds and it didn't work there
# ```

# %% [markdown]
# There is a session_ cookie. There are also cookies for https://www.youtube-nocookie.com. For the test_embed we have also a session_ cookie but no youtube cookie. Ironically though this is also now triggering the bot test when it wasn't yesterday. I wonder if a large number of calls for the same movie has triggered something in the algorithms.  Bottom line this is not a very robust way of doing things, maybe I am better to move to using bunny.net to serve the videos?

# %% [markdown]
# #### Develop Bunny.Net processing

# %% [markdown]
# I have blog-therichmond4.b-cdn.net. At present there is only one file, '2026_04_wharfdale.mp4'. Can we test this loads ok here

# %%
import httpx
r = httpx.head("https://blog-therichmond4.b-cdn.net/2026_04_wharfdale.mp4")
r.status_code
# Out:
# 200

# %% [markdown]
# Which type of video files with most browsers work with. I know .mp4 is ok, any others

# %%
def process_bunny_embed(page: NotStr, slug: str):
    page = str(page)
    pattern = r'''
    (<p[^>]*>)? # find and capture <p> if it is there.  Allows for intermediate characters after p but only up to >
    (\s*)? # Optional spaces between the tag and the start of the embedded code
    \{\{bunny:(?P<name>[A-Za-z0-9_]+)(?P<suffix>(\.mp4|\.webm))\}\} # catch the brackets, the name of the file and the suffix
    (\s*)?(</p>)? # Optional space after the brackets before the termination of the p tag
    '''
    
    def replace_bunny(match):
        file_name = match['name']
        suffix = match['suffix']
        video_type = match['suffix'][1:]
        src = f"https://{config.CDN}/{file_name+suffix}"
        poster_path = config.PROJECT_ROOT / config.POSTER_DIR / slug / Path(file_name+config.POSTER_SUFFIX + '.jpg')
        with open(poster_path, 'rb') as f:
            raw_bytes = f.read()
        poster = f"data:image/jpeg;base64,{base64.b64encode(raw_bytes).decode()}"
        ret_value = f'<video controls width="100%" poster="{poster}">\n  <source src="{src}" type="video/{video_type}">\n</video>'
        return ret_value
    
    page = re.sub(pattern, replace_bunny, page, flags=re.VERBOSE + re.MULTILINE)
    return NotStr(page)

# %%
#| export
def process_bunny_embed(page: NotStr, slug: str):
    page = str(page)
    pattern = r'''
    (<p[^>]*>)?
    (\s*)?
    \{\{bunny:(?P<path>[A-Za-z0-9_/-]*/)?(?P<name>[A-Za-z0-9_\-]+)(?P<suffix>(\.mp4|\.webm))\}\}
    (\s*)?
    (</p>)?
    '''
    
    def replace_bunny(match):
        path = match['path'] or ''
        file_name = match['name']
        suffix = match['suffix']
        video_type = suffix[1:]
        
        src = f"https://{config.CDN}/{path}{file_name}{suffix}"
        
        # Build poster path with flattened naming: folder_path_filename_poster.jpg
        path_prefix = path.replace('/', '_') if path else ''
        poster_name = f"{path_prefix}{file_name}{config.POSTER_SUFFIX}.jpg"
        poster_dir = config.PROJECT_ROOT / config.POSTER_DIR / slug
        poster_dir.mkdir(parents=True, exist_ok=True)
        poster_path = poster_dir / poster_name
        
        if not poster_path.exists():
            create_poster_image(src, poster_path)
            
        with open(poster_path, 'rb') as f:
            raw_bytes = f.read()
        poster = f"data:image/jpeg;base64,{base64.b64encode(raw_bytes).decode()}"
        
        return f'<video controls width="100%" poster="{poster}">\n  <source src="{src}" type="video/{video_type}">\n</video>'
    
    page = re.sub(pattern, replace_bunny, page, flags=re.VERBOSE + re.MULTILINE)
    return NotStr(page)

# %%
test_bunny = '''

And if you fancy a video:

{{bunny:2025_cannock/Cannock_Lenka_Seb_2025-vimeo.mp4}}

abcded
'''
slug = 'my-slug'

# %%
result = str(process_bunny_embed(NotStr(test_bunny), slug))

# %% [markdown]
# The above function is working but I realise that it only works with files in the top level of the CDN folder.  Is this designed to cope with very large file numbers or should I consider adapting it to deal with sub folders?

# %% [markdown]
# Whilst I am doing it I think it would make sense to have a optional folder, as you say, it will make management easier over time although the absolute numbers are unlikely to be that high

# %%
@route('/googleada316577537ad2b.html')
def get(): return 'google-site-verification: googleada316577537ad2b.html'

# %% [markdown]
# I would prefer it if we created the poster image on upload and then saved it at a convinient location in the server (maybe statics/posters/{slug}/filename? That is less manual work for me

# %%
test_bunny_content = '''
This is a test post excerpt to check the detection of embedded bunny links with the correct format

{{bunny:2026_04_wharfdale.mp4}}

And also the other type of video that I will work with:

{{bunny:2026_04_wharfdale.webm}}

Lets see if we can correctly extract these
'''

# %%
#| export
@route('/sitemap.xml')
def sitemap():
    slug_list = state.pdb.q("""SELECT p.slug FROM posts p WHERE p.private = False ORDER BY p.created""")
    slug_list = [slug['slug'] for slug in slug_list]
    base = "https://blog.therichmond4.co.uk"
    static_urls = ["/", "/about", "/blog"]
    urls = static_urls + [f"/blog/{slug}" for slug in slug_list]
    xml = '<?xml version="1.0" encoding="UTF-8"?>\n<urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">\n'
    xml += "\n".join(f"  <url><loc>{base}{u}</loc></url>" for u in urls)
    xml += "\n</urlset>"
    return Response(xml, media_type="application/xml")

# %% [markdown]
# When the posts are displayed they seem to be going in date order but based upon the modified date and not the created date. I just uploaded a post with a created date last year but it is showing as if it were created yesterday. Can you see where this is coming from?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Looking at your `process_upload` function, I can spot the issue. When uploading with overwrite, `created` is not passed to `add_post`:
#
# ```python
# if overwrite:
#     add_post(slug=slug, title=title, content=post.content, excerpt=excerpt, tags=tags, updated=updated, private=private)
# ```
#
# Then in `add_post`, when a post already exists:
#
# ```python
# post = posts.update(dict(..., created=created or now, ...))
# ```
#
# Since `created` is `None`, it falls back to `now` — overwriting your original date.
#
# The fix is simply to pass `created=created` in the overwrite branch of `process_upload`, the same way the non-overwrite branch does.
#
# <details class='token-usage-details' markdown='1'><summary>$0.3839</summary>
#
# `total=70,835 | in=70,111 | out=501 | cached=0.0% | cache_new=46,277 | reasoning=223 | $0.3839`
#
# </details>

# %%
from IPython.display import Image, display
config.PROJECT_ROOT, config.POSTER_DIR
path = config.PROJECT_ROOT / config.POSTER_DIR / 'grassington-to-parceval-hall-gardens' / '2026_04_wharfdale_poster.jpg'
with open(path, 'rb') as f:
    img = f.read()
display(Image(img))
# Out:
# Image(b'\xff\xd8\xff\xe0\x00\x10JFI…)

# %% [markdown]
# The above works fine on my mac but when somebody opened the blog post on an iphone there was just a play symbol and not a preview image where the movie should be. Do you know why that might be happening, and is there a way to load a placeholder image automatically as we did in the past with a youtube video?

# %% [markdown]
# #| export
# Post-processes rendered HTML to find Obsidian image syntax `![[image.jpg|width|position]]` and replace with styled `<img>` tags. Supports width, height, and positioning (left/right/center).

# %% [markdown]
# #### Add a sitemap generator

# %% [markdown]
# Custom markdown renderer that extends `FrankenRenderer`. Automatically adds `target="_blank"` and `rel="noopener noreferrer"` to external links (http/https).

# %% [markdown]
# I think it would be fine to create yt_hdrs in the cell above the create_app and then inject it as you suggest with the *yt_hdrs in create_app.  Do you think this will work ok?

# %% [markdown]
# ### Export

# %%
import nbdev
nbdev.nbdev_export()
