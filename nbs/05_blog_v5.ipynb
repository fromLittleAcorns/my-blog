# %% [markdown]
# ### Version 5
# This version features the ability to import the module without problems with the app having to be created during the load. This allows it to be deployed easily with a python app file and to change from a Jupyter server to a more straightforward uvicorn server
#
# Developments still to add in:
# 1. Add ability to delete posts from the UI if admin
# 2. Add ability to edit posts in situ
# 3. Check if there is a way to enable image layout in Obscidian

# %% [markdown]
# #| export
# ### Notes regarding the blog approach
#
# The blog posts are currently prepared using Obscidian. This means that the saved markdown is not the default mistletoe but a variant.  In particular images are handled differently.  In Obscidian the format is ![[image_path]].  There is also an option to control the size of the image using a format such as ![[image_path|250]].  This is built into Obsidian and renders ok within their app.  I have then added a justification option which is left, center, right, as follows: ![[image_path|250|right]].
#
# In the process_upload function images are uploaded to a path using the post slug as a directory name.  The slug is generated from the post title changed to lowercase and spaces replaced by underscores, and then truncated at 60 characters.  Thus a post titled "A visit to Spain" would have a slug of "a_visit_to_spain" and the images would be places in a folder: static/image/post_images/a_visit_to_spain.
#
# When displaying a post, the markdown is rendered as normal. After rendering a function process_obsician_images is used to generate css for the images based upon the obscidian image definition as above.  A similar approach is taken to processing strava embeddings since Strava does not support iframes. Strava embeddings are encoded as {{strava:17555511761}}, where the number is the strava ride id.

# %%
#| default_exp core_v5

# %% [markdown]
# Sets the default export module for nbdev. All cells marked `#| export` will be written to `my_blog/core_v5.py`.

# %%
#| hide
from nbdev.showdoc import *
import nbdev

# %%
#| export
from fastlite import Database
from pathlib import Path
from datetime import datetime, timedelta
import my_blog.config as config
from urllib.parse import quote, unquote
from fasthtml.common import *
from monsterui.all import *
from fasthtml_auth import AuthManager
from fasthtml.jupyter import *
import re
import frontmatter

# %% [markdown]
# #| export
# Core imports: `fastlite` for SQLite database, `fasthtml` and `monsterui` for web UI, `fasthtml_auth` for authentication, and `frontmatter` for parsing markdown with YAML metadata.

# %%
#| export
@dataclass
class AppState:
    pdb: Database # for managing posts
    posts_t: Table
    tags_t: Table
    post_tags_t: Table
    auth: AuthManager
    db: Database # For managing users and authorising access

# %% [markdown]
# #| export
# `AppState` holds all shared application state: the posts database, table references, and auth manager. Passed around instead of using globals.

# %%
#| export
def create_database_tables(pdb: Database):

    class Posts:
        id: int # primary key
        title: str
        slug: str # unique
        content: str
        created: datetime
        updated: datetime
        published: bool
        excerpt: str

    posts = pdb.create(Posts, pk='id', defaults={'published': False}, transform=True)
    posts.create_index(['slug'], unique=True, if_not_exists=True)

    class Tags:
        id: int # primary key
        name: str # unique
    
    tags = pdb.create(Tags, pk='id', transform=True)
    tags.create_index(['name'], unique=True, if_not_exists=True)

    class PostTags:
        post_id: int # foreign key > posts.id
        tag_id: int # foreign key > tags.id
    
    post_tags = pdb.create(PostTags, pk=['post_id', 'tag_id'], transform=True)

# %% [markdown]
# #| export
# Creates the three database tables: `Posts` (blog content), `Tags` (category names), and `PostTags` (many-to-many junction table linking posts to tags).

# %%
#| export
def create_post_database(db_path: str):
    pdb = Database(db_path)
    pdb.execute("PRAGMA foreign_keys = ON")
    create_database_tables(pdb)
    return pdb

# %% [markdown]
# #| export
# Convenience wrapper that creates a database connection and initializes all tables.

# %%
#| export
def create_app():
    # Create databases and apps, return these within and AppState class.
    # Once created then create the server with srv = serve()
    # Add the routes with rt = app.route
    pdb = create_post_database(config.POSTS_DB_PATH)
    posts_t = pdb.t.posts
    tags_t = pdb.t.tags
    post_tags_t = pdb.t.post_tags
    # Initialize auth database
    auth = AuthManager(
        db_path=str(config.USERS_DB_PATH),
        config={
            'allow_registration': config.ALLOW_REGISTRATION,
            'public_paths': ['/', '/about', r'/blog.*', r'/post.*', '/googleada316577537ad2b.html'],  # Let anybody see the site apart from the admin and auth routes
            'login_path': '/auth/login',
        }
    )
    db = auth.initialize()
    # Set db password
    admin = auth.get_user(config.ADMIN_USERNAME)
    if admin and config.ADMIN_PASSWORD: auth.user_repo.update(admin.id, password=config.ADMIN_PASSWORD, email=config.ADMIN_EMAIL)
    beforeware = auth.create_beforeware()
    hdrs = (*Theme.blue.headers(highlightjs=True), Script(src="https://unpkg.com/hyperscript.org@0.9.12"),
        Script(src="https://www.googletagmanager.com/gtag/js?id=G-DP7YB96KHH", async_=True),
        Script("window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-DP7YB96KHH');"),
        Link(rel="icon", type="image/png", href="/static/image/john_pixelated.png"))
    app = FastHTML(
        before=beforeware,
        secret_key=config.SECRET_KEY,
        hdrs=hdrs,
        exts='ws'  # Enable WebSocket support
    )
    config.STATIC_DIR.mkdir(parents=True, exist_ok=True)
    app.mount("/static", StaticFiles(directory=str(config.STATIC_DIR)), name="static")
    auth.register_routes(app, include_admin=True)
    state = AppState(
        pdb=pdb,
        posts_t=posts_t,
        tags_t=tags_t,
        post_tags_t=post_tags_t,
        auth=auth,
        db=db
    )
    return app, state

# %% [markdown]
# #| export
# Main app factory: initializes both databases, sets up authentication with `fasthtml-auth`, configures headers and static files, and returns the app plus an `AppState` instance.

# %%
#| export
# Route collection for deferred registration
_routes = []

def route(path=None):
    """Decorator to collect routes without registering them immediately.
    Use @route('/path') or @route() for function-name-based paths."""
    def decorator(f):
        _routes.append((path, f))
        return f
    if callable(path):  # @route without parens
        f, path = path, None
        _routes.append((path, f))
        return f
    return decorator

# %% [markdown]
# #| export
# Route collector decorator. Stores routes in `_routes` list for later registration. Supports both `@route` (path from function name) and `@route('/custom/path')` syntax.

# %%
#| export
def register_routes(app):
    """Register all collected routes with the app."""
    for path, handler in _routes:
        if path:
            app.route(path)(handler)
        else:
            app.route(handler)

# %% [markdown]
# #| export
# Registers all routes collected by `@route` with the given app. Call this in your `app.py` after importing the module.

# %% [markdown]
# Initializes and runs the app. `JupyUvi` is used for notebook testing; `rt` is a shorthand for `app.route`.

# %%
#| export
def intro():
    return Article(
        H3("Welcome to my Blog Site", cls="text-2xl font-semibold mb-4"),
        Div(cls="text-base gap-1 text-muted-foreground leading-relaxed space-y-4")(
        P("I created this site to keep a record of things I am interested in.  As such it will largely cover motorhome trips, cycling events and routes that I have done and enjoyed, coding and software development activities I am interested in or engaged with, and technology that I think is worth looking at.  You can find out more about me on my ", hx_link("About", "/about"), " page"),

        P("This site is developed using fastHTML and the Solveit platform, both technologies developed by Jeremy Howard and ",A('Answer.ai', href='https://answer.ai', target="_blank", rel="noopener noreferrer", cls="text-primary underline"), " The desgn is based upon the site of ", A('Jack Hogan.', href='https://jackhogan.net/', target="_blank", rel="noopener noreferrer", cls="text-primary underline"),

        " See my latest blog posts below or find the full list on my ", hx_link("Blog", "/blog"), " page, where posts can be readily filtered by topic.")
        )
    )

# %% [markdown]
# #| export
# Homepage intro section: returns an `Article` with welcome text and links to About and Blog pages using HTMX-enabled navigation.

# %%
#| export
def hx_attrs(target="#main-content"): return dict(hx_target=target, hx_push_url="true", hx_swap="innerHTML show:window:top")

def hx_link(txt, href, cls="text-primary underline", target="#main-content", **kw):
    return A(txt, href=href, hx_get=href, cls=cls, **hx_attrs(target), **kw)

# %% [markdown]
# #| export
# `hx_attrs` returns HTMX attributes for partial page updates. `hx_link` creates an anchor that uses both regular `href` and HTMX `hx-get` for SPA-like navigation.

# %%
#| export
def navbar():
    brand = A(Img(src="/static/image/john_pixelated.png", alt="John Richmond", cls="w-6 h-6 rounded-full"), Span("John Richmond "), href="/", hx_get="/", cls="flex items-center gap-2 text-lg font-bold", **hx_attrs())
    links = Div(hx_link("About", "/about"), hx_link("Blog", "/blog"), cls="flex gap-4")
    return Nav(Div(brand, links, cls="flex items-center gap-2 justify-between p-4"), cls="border rounded-lg shadow bg-background")

# %% [markdown]
# #| export
# Navigation bar with brand logo/name on the left and page links (About, Blog) on the right. Uses flexbox for layout.

# %%
#| export
def x_icon(): return Svg(ft_hx("path", d="M12.6.75h2.454l-5.36 6.142L16 15.25h-4.937l-3.867-5.07-4.425 5.07H.316l5.733-6.57L0 .75h5.063l3.495 4.633L12.601.75Zm-.86 13.028h1.36L4.323 2.145H2.865z"), width=20, height=20, fill="currentColor", viewBox="0 0 16 16", aria_hidden="true")

# %% [markdown]
# #| export
# Custom X (Twitter) icon as inline SVG—UIkit doesn't include the new X logo.

# %%
#| export
def social_link(icon, href, **kw):
    kw = dict(rel="nofollow noindex") if k == "mail" else dict(target="_blank", rel="noopener noreferrer")
    return A(x_icon() if k == "twitter" else UkIcon(icon, width=20, height=20), href=href, cls="hover:text-primary transition-colors", target="_blank", rel="noopener noreferrer", **kw)

def social_link(k, v):
    ext = dict(rel="nofollow noindex") if k == "mail" else {} if k == "rss" else dict(target="_blank", rel="noopener noreferrer")
    return A(x_icon() if k == "twitter" else UkIcon(k, width=20, height=20), href=v, aria_label=k.title(), cls="hover:text-primary transition-colors", **ext)


def footer():
    links = dict(twitter="https://x.com/@johnWrichmond", youtube="https://youtube.com/@confusedjohn46a", github="https://github.com/fromLittleAcorns")
    icons = Div(*[social_link(k, v) for k, v in links.items()], social_link("mail", "mailto:confusedjohn46@gmail.com"), cls="flex justify-center gap-6 text-muted-foreground")
    return Footer(Divider(), icons, cls="max-w-2xl mx-auto px-6 mt-auto mb-6")

# %% [markdown]
# #| export
# `social_link` creates social media icon links with appropriate `rel` attributes for security. `footer` assembles the page footer with social icons.

# %%
#| export
def layout(*content, htmx, title=None):
    ''' title here is used to set the browser tab label in the <head> section and will not be visible on the page.  The article title is appended into the main content and shows below the navbar
    '''
    if htmx and htmx.request: return (Title(title), *content)
    main = Main(*content, cls='w-full max-w-2xl mx-auto px-6 py-8 space-y-8', id="main-content")
    return Title(title), Div(Div(navbar(), cls='max-w-2xl mx-auto px-4 mt-4'), main, footer(), cls="flex flex-col min-h-screen")

# %% [markdown]
# #| export
# Page layout wrapper. On HTMX requests, returns just the content (for partial swap). On full page loads, wraps content with navbar and footer.

# %%
#| export
def slug_exists(slug):
    if bool(list(state.posts_t.rows_where("slug = ?", [slug], limit=1))):
        return list(state.posts_t.rows_where("slug = ?", [slug], limit=1))[0]['id']
    else:
        return False

# %% [markdown]
# #| export
# Checks if a slug already exists in the database. Returns the post ID if found, `False` otherwise. Used for update-vs-insert logic.

# %%
from datetime import datetime

# %%
#| export
def get_slug(title):
    slug = title.lower().replace(" ", "-")
    slug = ''.join(c for c in slug if c.isalnum() or c == '-')[:60]
    return slug

# %% [raw]
# def add_post(title, content, excerpt="", tags=None, published=True):
#     slug = get_slug(title)
#     posts = state.pdb.t.posts
#     tags_tbl = state.pdb.t.tags
#     post_tags = state.pdb.t.post_tags
#     post_id = slug_exists(slug)
#     if post_id:
#         post = posts.update(dict(id=post_id, title=title, slug=slug, content=content, excerpt=excerpt,
#                                     created=datetime.now(), updated=datetime.now(), published=published))
#     else:
#         post = posts.insert(dict(title=title, slug=slug, content=content, excerpt=excerpt,
#                                     created=datetime.now(), updated=datetime.now(), published=published))
#     post_id = post['id'] if isinstance(post, dict) else post.id
#     if tags:
#         if isinstance(tags, str): tags = [tags]  # Handle string as single tag
#         for tag in tags:
#             # Get existing tags
#             existing = list(tags_tbl.rows_where("name = ?", [tag], limit=1))
#             # If existing tag then load the relevant id.  If not then create a new one and get the id.
#             if existing:
#                 tag_id = existing[0]['id']
#             else:
#                 result = tags_tbl.insert(dict(name=tag))
#                 tag_id = result['id'] if isinstance(result, dict) else result.id
#                 # Implies no link exists for this post and tag so create one
#             if not list(post_tags.rows_where("post_id = ? AND tag_id = ?", [post_id, tag_id])):
#                 post_tags.insert(dict(post_id=post_id, tag_id=tag_id))
#     return post_id

# %% [markdown]
# # Example: add a post
# add_post(
#     title="My First Post",
#     content="This is the **content** in markdown.",
#     excerpt="A short summary",
#     tags=["coding", "technology"]
# )

# %% [markdown]
# #| export
# Creates or updates a post. Generates slug from title, handles tag creation/linking in the junction table. Updates existing posts if slug matches.

# %%
#| export
@route('/blog/{slug}')
def blogpost(htmx, req, slug: str):
    is_admin = check_if_admin(req)
    row = state.posts_t.rows_where("slug = ?", [slug], limit=1)
    p = next((dict(r) for r in row), None)
    if not p: return layout(H2("Not Found"), P("Post not found."), title="Not Found", htmx=htmx)
    p['created'] = datetime.fromisoformat(p['created']) if isinstance(p['created'], str) else p['created']
    content = render_md(p['content'], renderer=EnhancedRenderer)
    image_base = f"/static/image/post_images/{slug}"
    content = process_obsidian_images(content, image_base=image_base)
    content = process_strava_embeddings(content)
    admin_btns = Div(
        A("Edit", href=f'/admin/edit/{slug}', cls="uk-btn uk-btn-default uk-btn-xs"),
        # Button("Delete", hx_post=f"/admin/delete/{p['slug']}", hx_confirm="Delete this post?", 
        #    cls=["uk-btn uk-btn-default uk-btn-xs"]),
        Button("Delete", hx_post=f"/admin/delete/{slug}", hx_confirm="Delete this post?", 
            hx_swap="innerHTML", cls="uk-btn uk-btn-default uk-btn-xs"),
        A("Download", href=f"/admin/download/{p['slug']}", cls=[ButtonT.default, "uk-btn-xs"]),
        cls='flex gap-1'
    ) if is_admin else Div()
    return layout(H1(p['title'], cls="text-3xl font-bold mb-2"), Span(p['created'].strftime('%B %d, %Y'), cls="text-muted-foreground text-sm mb-8 block"), content, 
    admin_btns, Script(src="https://strava-embeds.com/embed.js"), title=p['title'], htmx=htmx)

# %% [markdown]
# #| export
# Route to display a single blog post. Fetches by slug, parses the datetime, renders markdown content with `render_md`, processes Obsidian images and Strava embeds.

# %%
#| export
@route
def index(htmx):
    posts = get_posts(n=4)
    items = [A(H3(p['title']), P(p['excerpt'], cls="text-muted-foreground"), Span(p['created'].strftime('%d %b %Y'), cls="text-sm text-muted-foreground"), href=f"/blog/{p['slug']}", hx_get=f"/blog/{p['slug']}", cls="block border-b pb-4 hover:bg-muted/50 transition-colors", **hx_attrs()) for p in posts]
    content = Div(*items, cls="space-y-4") if items else P("No posts yet.", cls="text-muted-foreground")
    return layout((intro(), Divider(), Section(H3("Latest Posts", cls="text-xl font-semibold mb-4"), content)), title="Welcome to my Blog", htmx=htmx)

# %% [markdown]
# #| export
# Homepage route: displays intro section, a divider, and the latest posts as cards.

# %%
#| export
def get_tags(tags_tbl):
    tags = [row.name for row in tags_tbl()]
    return tags

# %% [markdown]
# #| export
# Returns all tag names from the tags table as a list.

# %%
#| export
def get_post_tags(post_id: int):
    query = """
    SELECT name FROM tags WHERE id IN (SELECT tag_id FROM post_tags WHERE post_id=?)
    """
    tag_name_dicts = state.pdb.q(query, [post_id])
    tag_names = [name['name'] for name in tag_name_dicts]
    return tag_names

# %% [markdown]
# #| export
# Fetches all tags associated with a specific post via the `post_tags` junction table.

# %%
#| export
def get_posts(n: Union[int, None]=None, tags: Union[List, None] = None):
    if tags:
        place_holders = ','.join('?' * len(tags))
        query = f"""
            SELECT DISTINCT p.* FROM posts p
            JOIN post_tags pt ON p.id = pt.post_id
            JOIN tags t ON pt.tag_id = t.id
            WHERE t.name IN ({place_holders}) AND p.published = True
            ORDER BY p.created DESC
        """
        if n: query += f" LIMIT {n}"
        posts = state.pdb.q(query, tags)
    else:
        posts = list(state.posts_t.rows_where("published = ?", [True], order_by="created DESC", limit=n))
        posts = [dict(r) for r in posts]

    for p in posts:
        p['created'] = datetime.fromisoformat(p['created']) if isinstance(p['created'], str) else p['created']
        p['tags'] = get_post_tags(p['id'])
    return posts

# %% [raw]
# # Example: get recent posts, optionally filtered by tags
# posts = get_posts(n=5)  # Latest 5
# posts = get_posts(tags=['cycling', 'motorhome'])  # Filtered by tags

# %% [markdown]
# #| export
# Main post retrieval function. Optionally filters by tags and limits results. Returns dicts with parsed datetime and tag list attached.

# %%
#| export
def tag_pill(tag_name, selected_tags):
    if tag_name in selected_tags:
        new_tags = selected_tags - {tag_name}
        selected = True
    else:
        new_tags = selected_tags | {tag_name}
        selected = False
    link = f"/blog?tags={','.join(new_tags)}" if new_tags else "/blog"
    cls = [ButtonT.primary if selected else ButtonT.secondary, ButtonT.sm, "rounded-lg"]
    return Button(tag_name, cls=cls, hx_get=link, **hx_attrs("#posts-list"))

# %% [markdown]
# #| export
# Creates a clickable tag button. Clicking adds/removes the tag from the current filter. Selected tags are styled differently.

# %%
#| export
def tag_filter(selected):
    # Return a div containing all of the tags and their selection status. We also need a button to clear the current selection
    selected: set # a set containing the names of the selected tags
    tags = get_tags(state.tags_t)
    tag_pills = [tag_pill(tag_name, selected) for tag_name in tags]
    clear_btn = Button("X Clear", cls=[ButtonT.default, ButtonT.sm, "rounded-lg"], hx_get="/blog", **hx_attrs("#posts-list"))
    return Div(P("Filter: "), *tag_pills, clear_btn, cls="flex flex-wrap gap-2 items-center", id="tag-filter")

# %% [markdown]
# #| export
# Builds the tag filter bar: all tag pills plus a "Clear" button to reset filters.

# %%
#| export
def tag_badge(name):
    return Span(name, cls="text-xs px-2 py-1 rounded bg-muted")

# %% [markdown]
# #| export
# Small styled badge for displaying a tag name on post cards.b

# %%
#| export
@route
def blog(htmx, req, tags:str=None):
    # selected is a SET of the name of the selected tags
    selected = {unquote(t.strip()) for t in (tags or '').split(',') if t.strip()}
    filtered = get_posts(tags=selected)
    tag_filter_div = tag_filter(selected)
    items = [post_card(p, req) for p in filtered]
    post_content = Div(*items, cls="space-y-2", id="posts-list") if items else P("No posts yet.", cls="text-muted-foreground", id="posts-list")
    if htmx and htmx.target == "posts-list":
        tag_filter_div.attrs['hx-swap-oob'] = 'true'
        return post_content, tag_filter_div
    return layout(H2("Blog"), tag_filter_div, Divider(cls=('my-2')), post_content, title="Blog", htmx=htmx)

# %% [markdown]
# #| export
# Blog listing route. Parses tag filter from URL, fetches matching posts, renders tag filter + post cards. Uses HTMX OOB swap to update both filter and list on tag clicks.

# %%
#| export
def get_post_image(p):
    # check post content for image (/static/image/post_images/slug/*)
    # If image found then load a thumbnail of it
    img_ptn = r"!\[\[([^|\]]+?)(?:\|[^\]]+)?\]\]"
    imgs = re.findall(img_ptn,p["content"])
    img = imgs[0] if len(imgs)>0 else None
    if img:
        img_path = Path(img)
        slug = get_slug(p['title'])
        img_path = Path(config.POST_IMAGE_DIR) / Path(slug) / img_path
        return img_path
    else:
        return None

# %%
#| export
def check_if_admin(req):
    sess = req.scope.get('session', {})
    auth_username = sess.get('auth')
    user = state.auth.get_user(auth_username) if auth_username else None
    check_admin = is_admin = user and user.role == 'admin'
    return check_admin

# %% [markdown]
# #| export
# Extracts the first image path from a post's markdown content for use as a thumbnail.

# %% [raw]
# def post_card(p, req):
#     """Create a card to view a summary of the post including
#     - Title (linked)
#     - Excerpt
#     - possible thumbnail image if one is in the post, to the right of the text
#     - Date
#     - Tags as small pills?
#     - Hover effect?
#     """
#     is_admin = check_if_admin(req)
#     img_url = get_post_image(p)
#     admin_btns = [A("Edit", href=f'/admin/edit/{p['slug']}', cls=[ButtonT.secondary, ButtonT.sm]),
#                     Button("Delete", href=f"/admin/delete/{p['slug']}", cls=[ButtonT.warning, ButtonT.sm]),
#                     Button("Download", href=f"/admin/download/{p['slug']}", cls=[ButtonT.secondary, ButtonT.sm])
#     ] if is_admin else []
#     post = Div(cls="flex gap-2 p-3 -mx-3 rounded-lg hover:bg-muted/50 hover:shadow-lg transition-all cursor-pointer")(
#                 Div(cls="flex gap-4 border-b pb-4")(
#                     # Text column
#                     Div(cls="flex-1")(
#                         Div(A(H3(p['title'], href=f"/blog/{p['slug']}", hx_get=f"/blog/{p['slug']}", **hx_attrs())),
#                             P(p['excerpt'], cls="text-muted-foreground")),
#                         Div(cls='flex justify-between items-center w-full')(
#                             Div(Span(p['created'].strftime('%d %b %Y'), cls="text-sm text-muted-foreground"),
#                                 Div([tag_badge(tag) for tag in p["tags"]], cls="flex gap-2 flex-wrap")),
#                             Div(*admin_btns, cls='flex gap-2')
#                         )
#                     ),
#                     # Image
#                     Img(src=img_url, cls="p-4 max-w-48 h-auto object-contain ml-auto") if img_url else None)
#                 )
#
#     return post

# %% [markdown]
# This is the layout now.
#
#
# ![image.png](attachment:91fdb490-52c2-442f-93ef-e8ce5f333784)
#
#
# I think it would look better with the image to the right of the title and excerpt, with the date and tags below.  We could then put the buttons in the same row but I think they would need to be smaller again.  Also I need to make the edit look like a button, I thought using he button CSS would achieve that but it doesn't seem to have done so.  Would you suggest an alternative layout or if we adopt this can you suggest changes
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Looking at the screenshot, the main issues are: the Edit link isn't picking up button styles, and the buttons are too large relative to the date/tags row. Here's a revised version:
#
# ```python
# def post_card(p, req):
#     "Post summary card with optional admin controls"
#     is_admin = check_if_admin(req)
#     img_url = get_post_image(p)
#     slug = p['slug']
#     link_attrs = dict(href=f"/blog/{slug}", hx_get=f"/blog/{slug}", **hx_attrs())
#     admin_btns = Div(
#         A("Edit", href=f'/admin/edit/{slug}', cls="uk-btn uk-btn-default uk-btn-xs"),
#         Button('Delete', cls=[ButtonT.default, "uk-btn-xs"]),
#         Button('Download', cls=[ButtonT.default, "uk-btn-xs"]),
#         cls='flex gap-1'
#     ) if is_admin else Div()
#     return Div(cls="flex gap-4 p-3 -mx-3 rounded-lg border-b pb-4 hover:bg-muted/50 hover:shadow-lg transition-all")(
#         Div(cls="flex-1")(
#             A(H3(p['title']), P(p['excerpt'], cls="text-muted-foreground"), **link_attrs),
#             Div(cls='flex justify-between items-center mt-2')(
#                 Div(Span(p['created'].strftime('%d %b %Y'), cls="text-sm text-muted-foreground mr-2"),
#                     *[tag_badge(tag) for tag in p["tags"]], cls="flex items-center gap-2 flex-wrap"),
#                 admin_btns)),
#         A(Img(src=img_url, cls="max-w-36 h-auto object-contain rounded"), **link_attrs) if img_url else None)
# ```
#
# Key changes:
# - **Edit button**: using `uk-btn uk-btn-default uk-btn-xs` classes directly — MonsterUI's `ButtonT` classes are designed for `Button` components, but `A` tags need the raw UIkit classes
# - **All buttons `uk-btn-xs`**: much smaller to sit neatly alongside the date/tags
# - **Flatter structure**: outer flex has text on left, image on right; date/tags/buttons are a single row below the excerpt
# - **Image is wrapped in a link** too, so clicking it goes to the post
# - Unpacked the tag badges list with `*` so they sit inline with the date

# %%
#| export
def post_card(p, req):
    "Post summary card with optional admin controls"
    is_admin = check_if_admin(req)
    img_url = get_post_image(p)
    slug = p['slug']
    link_attrs = dict(href=f"/blog/{slug}", hx_get=f"/blog/{slug}", **hx_attrs())
    admin_btns = Div(
        A("Edit", href=f'/admin/edit/{slug}', cls="uk-btn uk-btn-default uk-btn-xs"),
        # Button("Delete", hx_post=f"/admin/delete/{p['slug']}", hx_confirm="Delete this post?", 
        #    cls=["uk-btn uk-btn-default uk-btn-xs"]),
        Button("Delete", hx_post=f"/admin/delete/{slug}", hx_confirm="Delete this post?", 
            hx_target="#main-content", hx_swap="innerHTML", 
            cls="uk-btn uk-btn-default uk-btn-xs"),
        A("Download", href=f"/admin/download/{p['slug']}", cls=[ButtonT.default, "uk-btn-xs"]),
        cls='flex gap-1'
    ) if is_admin else Div()
    return Div(cls="flex gap-4 p-3 -mx-3 rounded-lg border-b pb-4 hover:bg-muted/50 hover:shadow-lg transition-all")(
        Div(cls="flex-1")(
            A(H3(p['title']), P(p['excerpt'], cls="text-muted-foreground"), **link_attrs),
            Div(cls='flex justify-between items-center mt-2')(
                Div(Span(p['created'].strftime('%d %b %Y'), cls="text-sm text-muted-foreground mr-2"),
                    *[tag_badge(tag) for tag in p["tags"]], cls="flex items-center gap-2 flex-wrap"),
                admin_btns)),
        A(Img(src=img_url, cls="max-w-36 h-auto object-contain rounded"), **link_attrs) if img_url else None)

# %% [markdown]
# The buttons on teh above don't see to do anything, can I use href with Button
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# No, `href` doesn't work on `<button>` elements — that's an HTML limitation, not a FastHTML one. You have two options:
#
# 1. **Use `A` tags** styled as buttons (like you're already doing for Edit) — best for simple navigation like Download
# 2. **Use `hx_get`/`hx_post`** on the `Button` — better for actions like Delete where you want HTMX handling
#
# For your case I'd suggest making Download an `A` link and Delete an HTMX button:
#
# ```python
# admin_btns = Div(
#     A("Edit", href=f'/admin/edit/{slug}', cls="uk-btn uk-btn-default uk-btn-xs"),
#     Button("Delete", hx_post=f"/admin/delete/{slug}", hx_confirm="Delete this post?", cls="uk-btn uk-btn-default uk-btn-xs"),
#     A("Download", href=f"/admin/download/{slug}", cls="uk-btn uk-btn-default uk-btn-xs"),
#     cls='flex gap-1'
# ) if is_admin else Div()
# ```
#
# The `hx_confirm` on Delete gives you a browser confirmation dialog for free, which is nice for a destructive action.

# %% [markdown]
# If I make the whole thing clickable will that mean that the edit and other buttons will use that link or their own?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great question! Nesting an `A` inside another `A` is actually invalid HTML — browsers handle it unpredictably, and typically the outer link wins. So your Edit link and other buttons wouldn't work reliably.
#
# Two common solutions:
#
# 1. **Make only the title clickable** — simplest, and users expect to click titles anyway
# 2. **CSS trick** — make the card position-relative, stretch the title link over the whole card with CSS, and give the buttons a higher `z-index` so they sit "above" the card link
#
# Option 1 is much simpler. Want to go that route?

# %% [markdown]
# I am probably being dense but I can't see any difference between your code and that which I already have unless it is in a wider context?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# You're not being dense — the difference is really subtle! Look at this line in your code:
#
# ```python
# Div(cls='flex justify-between items-center w-full'), (
# ```
#
# There's a **comma** after the closing `)`. That makes it a tuple `(Div(...), (children...))` instead of a function call `Div(...)(children...)`.
#
# Remove that comma and it should work as intended.

# %% [markdown]
# #| export
# Renders a post summary card with title, excerpt, date, tags, and optional thumbnail. Entire card is clickable via HTMX.

# %% [raw]
# def process_upload(content: bytes, filename: str, slug:str=None):
#     # check there is no parent path element and if so just get the filename part
#     file_path = Path(filename)
#     if file_path.suffix == '.md':
#         try:
#             # post content, extract metadata and save contents to posts table
#             md_text = content.decode('utf-8')
#             post = frontmatter.loads(md_text)
#             title = post.metadata['title']
#             tags = post.metadata['tags']
#             excerpt = post.metadata['excerpt']
#             slug = title.lower().replace(" ", "-")
#             slug = ''.join(c for c in slug if c.isalnum() or c == '-')[:60]
#             # Convert obscidian image paths (note that this and convert markdown paths are removes as the work is to be done
#             # in process_obsidian+images
#             # content_rewritten = convert_obsidian_images(post.content, f"/static/image/post_images/{slug}")
#             # Convert normal markdown image paths
#             # content_rewritten = rewrite_image_paths( content_rewritten, slug)
#             # footerpost.content = content_rewritten
#             try:
#                 add_post(title=title, content=post.content, excerpt=excerpt, tags=tags)
#             except Exception as e:
#                 success = False
#                 message = f"Unable to save post: {e}"
#                 print(f'Error on save attempt: {e}')
#                 return success, message, None
#             return True, "Post saved", slug
#         except Exception as e:
#             return False, f"Error processing md: {type(e).__name__}: {e}", None
#
#     elif file_path.suffix in ['.jpg', '.png', '.jpeg', '.tif', '.svg']:
#         # file is an image, save to image folder
#         path_to_save = Path(config.POST_IMAGE_DIR) / Path(slug) / file_path.name
#         # Create directory if it doen't exist
#         path_to_save.parent.mkdir(parents=True, exist_ok=True)
#         path_to_save.write_bytes(content)
#         return True, f"File {path_to_save.name} saved", slug
#
#     else:
#         # unknown file type, raise an error Toast
#         return False, f"Unknown file type {filepath.suffix}", slug

# %% [markdown]
# I have added a capability to download a post that has been modified to Obsidian and then I want to be able to re-upload.  The post will not have a created and updated metadata fields. Can we adapt the process_upload and add_post functions to deal with these if they exist (they will not exist if the post has been created by the obsidian process)
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Here's the updated `add_post` — it now accepts optional `created`/`updated` params and falls back to `datetime.now()`:
#
# ```python
# def add_post(title, content, excerpt="", tags=None, published=True, created=None, updated=None):
#     slug = get_slug(title)
#     posts = state.pdb.t.posts
#     tags_tbl = state.pdb.t.tags
#     post_tags = state.pdb.t.post_tags
#     now = datetime.now()
#     post_id = slug_exists(slug)
#     if post_id:
#         post = posts.update(dict(id=post_id, title=title, slug=slug, content=content, excerpt=excerpt,
#                                  created=created or now, updated=now, published=published))
#     else:
#         post = posts.insert(dict(title=title, slug=slug, content=content, excerpt=excerpt,
#                                  created=created or now, updated=updated or now, published=published))
#     post_id = post['id'] if isinstance(post, dict) else post.id
#     if tags:
#         if isinstance(tags, str): tags = [tags]
#         for tag in tags:
#             existing = list(tags_tbl.rows_where("name = ?", [tag], limit=1))
#             if existing: tag_id = existing[0]['id']
#             else:
#                 result = tags_tbl.insert(dict(name=tag))
#                 tag_id = result['id'] if isinstance(result, dict) else result.id
#             if not list(post_tags.rows_where("post_id = ? AND tag_id = ?", [post_id, tag_id])):
#                 post_tags.insert(dict(post_id=post_id, tag_id=tag_id))
#     return post_id
# ```
#
# And the updated section of `process_upload` — just the markdown handling part where we extract the optional fields from frontmatter:
#
# ```python
# def process_upload(content: bytes, filename: str, slug:str=None):
#     file_path = Path(filename)
#     if file_path.suffix == '.md':
#         try:
#             md_text = content.decode('utf-8')
#             post = frontmatter.loads(md_text)
#             title = post.metadata['title']
#             tags = post.metadata['tags']
#             excerpt = post.metadata['excerpt']
#             created = post.metadata.get('created')
#             updated = post.metadata.get('updated')
#             slug = get_slug(title)
#             try:
#                 add_post(title=title, content=post.content, excerpt=excerpt, tags=tags, created=created, updated=updated)
#             except Exception as e:
#                 print(f'Error on save attempt: {e}')
#                 return False, f"Unable to save post: {e}", None
#             return True, "Post saved", slug
#         except Exception as e:
#             return False, f"Error processing md: {type(e).__name__}: {e}", None
#     elif file_path.suffix in ['.jpg', '.png', '.jpeg', '.tif', '.svg']:
#         path_to_save = Path(config.POST_IMAGE_DIR) / Path(slug) / file_path.name
#         path_to_save.parent.mkdir(parents=True, exist_ok=True)
#         path_to_save.write_bytes(content)
#         return True, f"File {path_to_save.name} saved", slug
#     else:
#         return False, f"Unknown file type {file_path.suffix}", slug
# ```
#
# Note I also fixed `filepath` → `file_path` in the last `else` branch — that would have been a `NameError`. And for updates, `updated` is always set to `now` since a re-upload is inherently a modification.

# %% [markdown]
# What will happen with the post.metadata.get if the field does not exist?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# `.get()` returns `None` when the key doesn't exist — that's standard dict behaviour. Then in `add_post`, the `created or now` expression will fall back to `datetime.now()` since `None` is falsy. So it handles the missing field case correctly without any extra code needed.

# %%
#| export
def add_post(title, content, excerpt="", tags=None, published=True, created=None, updated=None, slug: str=None):
    if not slug:
        slug = get_slug(title)
    posts = state.pdb.t.posts
    tags_tbl = state.pdb.t.tags
    post_tags = state.pdb.t.post_tags
    now = datetime.now()
    post_id = slug_exists(slug)
    if post_id:
        post = posts.update(dict(id=post_id, title=title, slug=slug, content=content, excerpt=excerpt,
                                 created=created or now, updated=now, published=published))
    else:
        post = posts.insert(dict(title=title, slug=slug, content=content, excerpt=excerpt,
                                 created=created or now, updated=updated or now, published=published))
    post_id = post['id'] if isinstance(post, dict) else post.id
    if tags:
        if isinstance(tags, str): tags = [tags]
        for tag in tags:
            existing = list(tags_tbl.rows_where("name = ?", [tag], limit=1))
            if existing: tag_id = existing[0]['id']
            else:
                result = tags_tbl.insert(dict(name=tag))
                tag_id = result['id'] if isinstance(result, dict) else result.id
            if not list(post_tags.rows_where("post_id = ? AND tag_id = ?", [post_id, tag_id])):
                post_tags.insert(dict(post_id=post_id, tag_id=tag_id))
    return post_id

# %%
def post_exists(slug: str) -> bool:
    return bool(_state.posts_t(where='slug=?', vals=[slug]))

# %%
#| export
def process_upload(content: bytes, filename: str, slug:str=None, overwrite: bool=False):
    file_path = Path(filename)
    if file_path.suffix == '.md':
        try:
            md_text = content.decode('utf-8')
            post = frontmatter.loads(md_text)
            title = post.metadata['title']
            tags = post.metadata['tags']
            excerpt = post.metadata['excerpt']
            created = post.metadata.get('created')
            updated = post.metadata.get('updated')
            # Get the slug from the post if it exists, if not then create a slug
            slug = post.metadata.get('slug') or get_slug(title)
            if not overwrite and slug_exists(slug):
                return 'confirm', "Post already exists. Overwrite?", slug
            try:
                if overwrite:
                    add_post(slug=slug, title=title, content=post.content, excerpt=excerpt, tags=tags, updated=updated)
                else:
                    add_post(title=title, content=post.content, excerpt=excerpt, tags=tags, created=created, updated=updated)
            except Exception as e:
                print(f'Error on save attempt: {e}')
                return False, f"Unable to save post: {e}", None
            return True, "Post saved", slug
        except Exception as e:
            return False, f"Error processing md: {type(e).__name__}: {e}", None
    elif file_path.suffix in ['.jpg', '.png', '.jpeg', '.tif', '.svg']:
        path_to_save = Path(config.POST_IMAGE_DIR) / Path(slug) / file_path.name
        path_to_save.parent.mkdir(parents=True, exist_ok=True)
        path_to_save.write_bytes(content)
        return True, f"File {path_to_save.name} saved", slug
    else:
        return False, f"Unknown file type {file_path.suffix}", slug

# %% [markdown]
# #| export
# Processes uploaded files. For `.md` files: parses frontmatter, rewrites image paths, saves to database. For images: saves to post-specific subfolder.

# %%
#| export
@route('/admin/upload')
def get(htmx):
    # Create file upload form for the post
    return Div(Div(A('Cancel', href='/', cls=f"{ButtonT.secondary} px-4 py-2"), Upload("Upload Button!", id='upload1', multiple=True), cls='flex gap-2'),
               Div(id='upload-message'),
               Form(
                UploadZone(DivCentered(Span("Upload Zone"), UkIcon("upload")), id='upload2', accept=['.md', '.jpg', '.jpeg', 'png', 'svg', 'gif'], multiple=True,
                hx_target='#upload-message', hx_trigger='change', hx_post='/admin/upload', hx_swap='innerHTML', hx_encoding="multipart/form-data"),
                cls='space-y-4')
    )

# %%
#| export
def save_pending(slug: str, md_name: str, md_content: bytes, images: list[tuple[str, bytes]]):
    """Save md content and images to temp storage keyed by slug.
    images is a list of (filename, bytes) tuples."""
    import pickle
    Path(f'/tmp/pending_{slug}.pkl').write_bytes(pickle.dumps({'name': md_name, 'md': md_content, 'images': images}))

# %%
#| export
def load_pending(slug: str):
    """Returns (md_content, images) or None if not found."""
    import pickle
    p = Path(f'/tmp/pending_{slug}.pkl')
    if not p.exists(): return None
    data = pickle.loads(p.read_bytes())
    return data['name'], data['md'], data['images']

# %%
#| export
def clear_pending(slug: str):
    Path(f'/tmp/pending_{slug}.pkl').unlink(missing_ok=True)

# %%
@route('/admin/upload')    
def post(upload2: list[UploadFile]):
    files = [(f.filename, f.file.read()) for f in upload2]
    md_files = [(n, c) for n, c in files if n.endswith('.md')]
    img_files = [(n, c) for n, c in files if not n.endswith('.md')]
    results = []
    slug = None
    if img_files and len(md_files)==0:
        return Div(Alert("Please upload a post (.md file) with images, or upload images separately", cls=AlertT.warning))
    for name, content in md_files:
        success, message, slug = process_upload(content, name)
        results.append((name, success, message))
    for name, content in img_files:
        success, message, _ = process_upload(content, name, slug=slug)
        results.append((name, success, message))
    header = ["Name", 'Success', 'Message']
    body = [[r[0], r[1], r[2]] for r in results]
    return Div(H2("Post upload results"), TableFromLists(header, body))

# %% [markdown]
# I am trying to set things up so that when I try to re-upload a post (after having modified it externally), I want to check if the slug already exists and if so confirm before I overwrite.  The process you suggested in another dialogue was:
#
# 'You're absolutely right — the .md file determines whether the post exists, so the flow should be:
#
# 1. /admin/upload receives the file list, processes the .md file first via process_upload()
# 2. If 'confirm' → save pending content, stash the image files too (or their bytes), return confirmation dialog. No images saved yet.
# 3. If True → post saved, now process and save the images
# 4. On overwrite confirm → /admin/upload/overwrite saves the post, then saves the stashed images'
#
# I have added functions to load_pending and save_pending files
#
# I am still puzzled by the flow.  I initially call /admin/upload.  This calls process upload. overwrite is false at this point.  If the slug is found to already exist then I return a dialogue to confirm whether or not to overwrite.  If I want to then I call /admin/upload/overwrite, which will save the post and then the images, then clears the stash.  I then need to return to create the table that is returned by the upload process.
#
# In reality I think I need to refactor the code that saves the files and images and return the table, and call this from the admin/upload/overwrite and /admin/upload routes to avoid code duplication etc.  Can you review the above and suggest an outline way to manage this from the routes, and how to adapt process_upload
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Your thinking is right. Here's a clean outline:
#
# **Refactor into a helper:**
# ```python
# def do_upload(md_files, img_files, overwrite=False): ...
#     # processes all files, returns results table
# ```
#
# **`POST /admin/upload`** — calls `do_upload(overwrite=False)`:
# - If any result is `'confirm'` → `save_pending(slug, md_content, img_files)`, return confirmation dialog with a button pointing to `/admin/upload/overwrite?slug={slug}`
# - Otherwise → return results table as normal
#
# **`POST /admin/upload/overwrite?slug=`** — loads pending, calls `do_upload(overwrite=True)`, clears pending, returns results table
#
# For `process_upload`, the key change is that when `overwrite=False` and slug exists, it should return `('confirm', message, slug)` **without saving anything** — which it already does in your current code. Good.
#
# One thing to consider: do you want to handle the case where multiple `.md` files are uploaded at once, where one needs confirmation and another doesn't? That complicates things — it may be simpler to restrict uploads to one `.md` at a time.
#
# Shall I sketch out the `do_upload` helper and the two routes in more detail?
#
# <details class='token-usage-details'><summary>$0.1119</summary>
#
# `total=46,986 | in=46,639 | out=347 | cached=64.3% | cache_new=13,982 | $0.1119`
#
# </details>

# %% [markdown]
# I am limiting it to one blog post and hence one md file at a time (althoug there is no actual restriction in place yet, that can come later). The above makes sense, yes please let me have a do_upload function and sketch out the routes, I will try to put the details in place if necessary
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Here's the `do_upload` helper and route sketches:
#
# ```python
# def do_upload(md_files, img_files, overwrite=False):
#     results = []
#     slug = None
#     for name, content in md_files:
#         success, message, slug = process_upload(content, name, overwrite=overwrite)
#         if success == 'confirm':
#             save_pending(slug, content, img_files)
#             return 'confirm', slug
#         results.append((name, success, message))
#     for name, content in img_files:
#         success, message, _ = process_upload(content, name, slug=slug)
#         results.append((name, success, message))
#     header = ["Name", "Success", "Message"]
#     return 'done', TableFromLists(header, [[r[0], r[1], r[2]] for r in results])
# ```
#
# ```python
# @route('/admin/upload')
# def post(upload2: list[UploadFile]):
#     files = [(f.filename, f.file.read()) for f in upload2]
#     md_files = [(n, c) for n, c in files if n.endswith('.md')]
#     img_files = [(n, c) for n, c in files if not n.endswith('.md')]
#     status, result = do_upload(md_files, img_files)
#     if status == 'confirm':
#         slug = result
#         # return a confirmation dialog - result is the slug
#         return Div(P("Post already exists. Overwrite?"),
#                    Button("Yes, overwrite", hx_post=f"/admin/upload/overwrite?slug={slug}", hx_target="#upload-message", hx_swap="innerHTML"),
#                    Button("Cancel", cls=ButtonT.secondary, hx_get="/admin/upload", hx_target="#upload-message", hx_swap="innerHTML"))
#     return Div(H2("Upload results"), result)
# ```
#
# ```python
# @route('/admin/upload/overwrite')
# def post(slug: str):
#     pending = load_pending(slug)
#     if not pending: return Alert("No pending upload found", cls=AlertT.warning)
#     md_content, img_files = pending
#     status, result = do_upload([(slug + '.md', md_content)], img_files, overwrite=True)
#     clear_pending(slug)
#     return Div(H2("Upload results"), result)
# ```
#
# The main thing you'll need to fill in is the confirmation dialog styling. Does this flow look right to you?
#
# <details class='token-usage-details'><summary>$0.0513</summary>
#
# `total=47,708 | in=47,066 | out=642 | cached=93.4% | cache_new=2,810 | $0.0513`
#
# </details>

# %%
#| export
def do_upload(md_files, img_files, slug: str=None, overwrite: bool=False):
    results = []
    for name, content in md_files:
        success, message, slug_from_title = process_upload(content, name, overwrite=overwrite)
        if not slug:
            slug = slug_from_title
        if success == 'confirm':
            save_pending(slug, name, content, img_files)
            return 'confirm', slug
        results.append((name, success, message))
    for name, content in img_files:
        success, message, _ = process_upload(content, name, slug=slug)
        results.append((name, success, message))
    header = ["Name", "Success", "Message"]
    return 'done', TableFromLists(header, [[r[0], r[1], r[2]] for r in results])

# %%
#| export
@route('/admin/upload')
def post(upload2: list[UploadFile]):
    files = [(f.filename, f.file.read()) for f in upload2]
    md_files = [(n, c) for n, c in files if n.endswith('.md')]
    img_files = [(n, c) for n, c in files if not n.endswith('.md')]
    status, result = do_upload(md_files, img_files)
    if status == 'confirm':
        slug = result
        # return a confirmation dialog - result is the slug
        return Div(P("Post already exists. Overwrite?"),
                   Button("Yes, overwrite", hx_post=f"/admin/upload/overwrite?slug={slug}", hx_target="#upload-message", hx_swap="innerHTML"),
                   Button("Cancel", cls=ButtonT.secondary, hx_get="/admin/upload", hx_target="#upload-message", hx_swap="innerHTML"))
    return Div(H2("Upload results"), result)

# %%
#| export
@route('/admin/upload/overwrite')
def post(slug: str):
    pending = load_pending(slug)
    if not pending: return Alert("No pending upload found", cls=AlertT.warning)
    md_name, md_content, img_files = pending
    status, result = do_upload([(md_name, md_content)], img_files, slug=slug, overwrite=True)
    clear_pending(slug)
    return Div(H2("Upload results"), result)

# %% [markdown]
# When I try to upload a post that has been modified using the route /admin/upload then I get the following error message:
#   File "/app/data/my-blog/my_blog/core_v5.py", line 498, in post
#     status, result = do_upload([(md_name, md_content)], img_files, slug=slug, overwrite=True)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/app/data/my-blog/my_blog/core_v5.py", line 472, in do_upload
#     success, message, _ = process_upload(content, name, slug=slug)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/app/data/my-blog/my_blog/core_v5.py", line 423, in process_upload
#     path_to_save = Path(config.POST_IMAGE_DIR) / Path(slug) / file_path.name
#                                                  ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/pathlib.py", line 1162, in __init__
#     super().__init__(*args)
#   File "/usr/local/lib/python3.12/pathlib.py", line 373, in __init__
#     raise TypeError(
# TypeError: argument should be a str or an os.PathLike object where __fspath__ returns a str, not 'NoneType'
#
# I can't see why slug should be none, it should be passed into the overwrite route and then passed into do_upload and then process_upload?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# The problem is in `do_upload` — the md_files loop reassigns `slug` from `process_upload`'s return value:
#
# ```python
# success, message, slug = process_upload(content, name, overwrite=overwrite)
# ```
#
# If that call fails (returns `None` for slug), it overwrites the `slug` parameter you passed in. And I suspect it *is* failing — because `process_upload` calls `update_post()` when `overwrite=True`, but I don't see `update_post` defined anywhere. That would raise a `NameError`, get caught by the `except`, and return `(False, msg, None)`.
#
# Two fixes needed:
#
# 1. Either define `update_post`, or just use `add_post` in both branches of `process_upload` — since `add_post` already handles the update-if-slug-exists logic
# 2. In `do_upload`, don't overwrite the `slug` parameter — use a different variable name, or check for failure before continuing to images
#
# <details class='token-usage-details'><summary>$0.2747</summary>
#
# `total=51,040 | in=49,042 | out=1,998 | cached=60.9% | cache_new=17,895 | $0.2747`
#
# </details>

# %% [markdown]
# ###### end-section

# %% [markdown]
# I don't think this is correct as the filename of the md file is not necessarily going to be slug + '.md'. The filename surely needs to come from the originally supplied name? I think that this flaw is built into the load and save pending functions as well. Do you agree or have I misunderstood?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You're absolutely right. The filename needs to be preserved alongside the content. The fix is to store it in `save_pending` and restore it in `load_pending`.
#
# So `save_pending` should store `(filename, md_content)` instead of just `md_content`, and `load_pending` should return that tuple. Then in the overwrite route you use the stored filename rather than reconstructing it from the slug.
#
# Do you want to try updating those three functions yourself, or would you like me to show the changes?
#
# <details class='token-usage-details'><summary>$0.2733</summary>
#
# `total=48,412 | in=48,294 | out=118 | cached=0.0% | cache_new=47,386 | $0.2733`
#
# </details>

# %% [markdown]
# #| export
# Admin upload handler (POST): processes markdown files first (to get slug), then images. Returns a results table showing success/failure for each file.

# %%
#| export
def rewrite_image_paths(content: str, slug: str) -> str:
    # img_ptn = r"!\[.*?\]\((/static/image/post_images/[^)]+)\)"
    img_ptn = r"(!\[.*?\])\(([^/)]+\.(jpg|jpeg|png|gif|svg))\)"
    replacement = rf"\1(/static/image/post_images/{slug}/\2)"
    return re.sub(img_ptn, replacement, content, flags=re.IGNORECASE)

# %% [markdown]
# #| export
# Rewrites simple image filenames like `![](image.jpg)` to full paths like `![](/static/image/post_images/{slug}/image.jpg)`. Called at upload time.

# %%
#| export
def convert_obsidian_images(content: str, image_base: str = "/static/image/about") -> str:
    """Convert Obsidian ![[image.ext]] syntax to standard markdown ![](/path/image.ext)"""
    # pattern = r'!\[\[([^\]]+\.(jpg|jpeg|png|gif|svg))\]\]'
    pattern = r'!\[\[([^|\]\n]+\.(?:jpg|jpeg|png|gif|svg))(?:[\\|][^\]]+)?\]\]'
    replacement = rf'![]({image_base}/\1)'
    return re.sub(pattern, replacement, content, flags=re.IGNORECASE)

def load_md_file(path: str, image_base: str = None) -> str:
    """Load markdown file, optionally converting Obsidian image syntax"""
    content = Path(path).read_text()
    if image_base:
        content = convert_obsidian_images(content, image_base)
    return content

# %%
test_img_1_content = '''test string with obscidian markdown, first without a table:
![[IMG_3932.jpeg]]
next with size:
![[IMG_3932.jpeg|250]]
and with size and position:
![[IMG_3932.jpeg|250|right]]
Then some rubbish
'''
base_path = "/static/image/post_images/post_1"
converted = convert_obsidian_images(test_img_1_content, base_path)
converted
# Out:
# 'test string with obscidian markdown, first without a table:\n![](/static/image/post_images/post_1/IMG_3932.jpeg)\nnext with size:\n![](/static/image/post_images/post_1/IMG_3932.jpeg)\nand with size and position:\n![](/static/image/post_images/post_1/IMG_3932.jpeg)\nThen some rubbish\n'

# %% [markdown]
# #| export
# `convert_obsidian_images` converts Obsidian's `![[image.ext]]` syntax to standard markdown. `load_md_file` loads a markdown file and optionally converts image syntax.

# %%
#| export
def about_content():
    md = load_md_file(config.STATIC_DIR / "content/About.md", image_base="/static/image/about")
    return render_md(md)

# %% [markdown]
# #| export
# Loads and renders the About page from a markdown file, converting Obsidian image syntax to proper paths.

# %%
#| export
@route
def about(htmx):
    return layout(about_content(),title="About Me", htmx=htmx)

# %% [markdown]
# #| export
# Route to display the About page.

# %%
#| export
def strava_embed(activity_id: str):
    return Div(cls="strava-embed-placeholder", data_embed_type="activity", data_embed_id=activity_id, data_style="standard")

# %%
# In your markdown, use:
# {{strava:12345678}}
# This will be replaced with an embedded Strava activity

# %% [markdown]
# Returns a Strava embed div with the given activity ID. The Strava embed.js script (loaded in headers) will transform this into a full embed.

# %%
#| export
def process_strava_embeddings(page: NotStr):
    page = str(page)
    # Pattern to match {{strava:ID}} possibly wrapped in <p> tags
    pattern_placeholder = r'(<p[^>]*>)?\s*\{\{strava:(\d+)\}\}\s*(</p>)?'
    
    def replace_strava(match):
        activity_id = match.group(2)
        return to_xml(strava_embed(activity_id))
    
    page = re.sub(pattern_placeholder, replace_strava, page)
    return NotStr(page)

# %% [markdown]
# Post-processes rendered HTML to find `{{strava:ID}}` placeholders and replace them with actual Strava embed divs.

# %%
#| export
def process_obsidian_images(page: NotStr, image_base: str) -> NotStr:
    page = str(page)
    pattern = new3 = r'''!\[\[(?P[^\]]+\.(jpg|jpeg|png|gif|svg)) # Image part, must be present
(?:\|(?P<size1>\d+))? # First size dimension (with leading pipe symbol (optional)
(?:x(?P<size2>\d+))? # Second size dimension (with leading x)
(?:\|(?P<location>left|right|center))?
\]\] # End of image (must be present)
'''
    
    for match in re.finditer(pattern, page, re.MULTILINE + re.VERBOSE):
        m = match.groupdict()
        
        # 1. Build src path
        src = f"{image_base}/{m['image']}"
        
        # 2. Build style string from size1, size2, location
        styles = []
        if m['size1']:
            styles.append(f"width: {m['size1']}px")
        if m['size2']:
            styles.append(f"height: {m['size2']}px")
        if m['location'] == 'center':
            styles.append("display: block; margin: auto")
        elif m['location'] == 'right':
            styles.append("float: right; margin-left: 1rem")
        elif m['location'] == 'left':
            styles.append("float: left; margin-right: 1rem")
        
        style_str = "; ".join(styles)
        
        # 3. Build img tag and replace
        img_tag = f'<img src="{src}" style="{style_str}">'
        page = page.replace(match.group(0), img_tag)
    
    return NotStr(page)

# %%
# Obsidian image syntax examples:
# ![[image.jpg|300]]           - width 300px
# ![[image.jpg|300|right]]     - float right, text wraps
# ![[image.jpg|300x200|center]] - fixed size, centered

# %% [markdown]
# Post-processes rendered HTML to find Obsidian image syntax `![[image.jpg|width|position]]` and replace with styled `<img>` tags. Supports width, height, and positioning (left/right/center).

# %%
#| export
from mistletoe import Document
from monsterui.franken import FrankenRenderer

# %% [markdown]
# Additional imports for the custom markdown renderer.

# %%
#| export
class EnhancedRenderer(FrankenRenderer):
    def _is_external(self, url):
        return url.startswith(('http://', 'https://', '//'))

    def render_link(self, token):
        target = self.escape_url(token.target)      
        title = f' title="{self.escape_html(token.title)}"' if token.title else ''
        inner = self.render_inner(token)

        # Determine if we need the new tab attributes
        extra_attrs = ' target="_blank" rel="noopener noreferrer"' if self._is_external(target) else ''

        return f'<a href="{target}"{extra_attrs}{title}>{inner}</a>'

    def render_autolink(self, token):
        target = self.escape_url(token.target)
        inner = self.render_inner(token)
        
        # Autolinks are almost always external, but we'll check anyway
        extra_attrs = ' target="_blank" rel="noopener noreferrer"' if self._is_external(target) else ''
        
        return f'<a href="{target}"{extra_attrs}>{inner}</a>'

    def render_paragraph(self, token):
        if self._suppress_ptag_stack[-1]: return self.render_inner(token)
        return f'<p class="text-lg leading-relaxed mb-6">{self.render_inner(token)}</p>'

# %% [markdown]
# I have a link in a table in a markdown post file.  When it is rendered it shows as below:
# | Eye Bolts - M5                         | [[https://www.amazon.co.uk/12PCS-Lifting-Threaded-Fastener-Stainless/dp/B07RW6HLRB\|Link]] | Amazon |
# Can you explain why this is happening and what I should do about it.  The post .md file was generated in Obsidian
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# This is an Obsidian-specific link format. In Obsidian, `[[url\|text]]` is their internal wiki-link syntax, but used here for an external URL. Standard markdown expects `[text](url)` instead.
#
# Your `EnhancedRenderer` handles standard markdown links fine, but the Obsidian wiki-link format isn't being converted — it's passing through as raw text into the rendered HTML.
#
# You have two options:
#
# 1. **Fix it in Obsidian** — use standard markdown link syntax `[Link](https://...)` when writing posts intended for export
# 2. **Add a conversion step** in `process_obsidian_images` (or a new function) to detect and rewrite `[[url\|text]]` patterns to standard `[text](url)` before rendering
#
# Option 1 is simplest if you're happy to change your writing habit. Option 2 is more robust if you want Obsidian wiki-link syntax to "just work".
#
# Which would you prefer?
#
# <details class='token-usage-details'><summary>$0.1814</summary>
#
# `total=32,132 | in=31,898 | out=234 | cached=0.0% | cache_new=28,947 | $0.1814`
#
# </details>

# %% [markdown]
# I have used option 1 and it works fine, that will be ok for now.  What do I need to enable Google to scan the site (if anything) and to add Google analytics
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great that option 1 worked! These are two separate things:
#
# 1. **Google Search Console** — lets Google discover and index your site. You verify ownership by adding a `<meta>` tag to your page `<head>`, then submit your sitemap.
#
# 2. **Google Analytics** — tracks visitor behaviour. You add a small `<script>` tag to every page's `<head>`.
#
# Both are added via your `hdrs` in `create_app()`, which is the right place since those headers appear on every page.
#
# Do you want to tackle them one at a time, starting with Search Console?
#
# <details class='token-usage-details'><summary>$0.1308</summary>
#
# `total=32,367 | in=32,229 | out=138 | cached=31.9% | cache_new=21,683 | $0.1308`
#
# </details>

# %% [markdown]
# Yes lets do that
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great! Here's how to get started:
#
# 1. Go to [Google Search Console](https://search.google.com/search-console) and sign in
# 2. Click **Add property** and enter your site's URL
# 3. Google will give you a `<meta>` verification tag that looks like:
#    ```html
#    <meta name="google-site-verification" content="your-code-here" />
#    ```
#
# You add that to your `hdrs` tuple in `create_app()` using FastHTML's `Meta()` component.
#
# Have you got a Search Console account set up, and do you have your site's domain ready to add?
#
# <details class='token-usage-details'><summary>$0.0200</summary>
#
# `total=32,575 | in=32,426 | out=149 | cached=98.6% | cache_new=235 | $0.0200`
#
# </details>

# %% [markdown]
# google has provided me with a html file it says needs to be put into the home directory of by blog to verify the site.  Where will I find this on the ubuntu server and how should I put it there?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Rather than placing the file on the server filesystem, there's a cleaner approach for a FastHTML app — serve it directly as a route. That way you don't need to worry about filesystem paths.
#
# The file will have a name like `google1234abcd.html` and contain a short string. You can serve it with a one-liner route:
#
# ```python
# @route('/google1234abcd.html')
# def get(): return 'google-site-verification: google1234abcd.html'
# ```
#
# The exact filename and content string are shown in Search Console. Does that approach appeal to you, or would you prefer to place the file on the filesystem?
#
# <details class='token-usage-details'><summary>$0.1336</summary>
#
# `total=32,822 | in=32,674 | out=148 | cached=31.5% | cache_new=22,126 | $0.1336`
#
# </details>

# %%
#| export
@route('/googleada316577537ad2b.html')
def get(): return 'google-site-verification: googleada316577537ad2b.html'

# %% [markdown]
# I will do that but lets look at the next action as well whilst your cache remains active
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# For Google Analytics:
#
# 1. Go to [analytics.google.com](https://analytics.google.com) and create an account/property for your site
# 2. Google will give you a **Measurement ID** (looks like `G-XXXXXXXXXX`) and a script tag to add to every page
#
# The script goes into your `hdrs` in `create_app()` alongside the verification meta tag. FastHTML's `Script()` component handles this.
#
# Go ahead and set up both accounts, then come back with the two codes and we can add them both to `hdrs` in one go!
#
# <details class='token-usage-details'><summary>$0.0197</summary>
#
# `total=32,784 | in=32,650 | out=134 | cached=98.7% | cache_new=208 | $0.0197`
#
# </details>

# %% [markdown]
# I have setup an account and have the following to insert into the page header:
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DP7YB96KHH"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-DP7YB96KHH');
# </script>
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# In FastHTML you translate those two `<script>` tags into your `hdrs` tuple like this:
#
# ```python
# Script(src="https://www.googletagmanager.com/gtag/js?id=G-DP7YB96KHH", async_=True),
# Script("window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-DP7YB96KHH');"),
# ```
#
# Just add those two lines to your `hdrs` tuple in `create_app()`. Note `async_` with an underscore — Python doesn't allow `async` as a keyword argument directly.
#
# <details class='token-usage-details'><summary>$0.1426</summary>
#
# `total=34,378 | in=34,208 | out=170 | cached=30.1% | cache_new=23,574 | $0.1426`
#
# </details>

# %% [markdown]
# I sometimes run a development version of this blog from a different url.  Will this cause a problem (ie do I need to set up a conditional flag to only add this when its launched from the prod version of the site?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# It won't cause any functional problems, but it does mean your development activity (page views, clicks etc.) will show up in your Analytics data and skew your stats.
#
# The simplest fix is to add a flag in your `config.py`:
#
# ```python
# ANALYTICS_ENABLED = True  # Set to False in dev
# ```
#
# Then wrap the analytics scripts conditionally in `create_app()`. Want to try writing that yourself?
#
# <details class='token-usage-details'><summary>$0.1431</summary>
#
# `total=34,674 | in=34,577 | out=97 | cached=29.8% | cache_new=24,027 | $0.1431`
#
# </details>

# %% [markdown]
# I think it would be better to add to my .env file as this will be different for both dev and prod without me having to change anything
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# That's a cleaner approach — you'd just set `ANALYTICS_ENABLED=true` in your prod `.env` and `ANALYTICS_ENABLED=false` in dev. Give it a try and let me know if you hit any issues reading it in `config.py`!
#
# <details class='token-usage-details'><summary>$0.0191</summary>
#
# `total=34,822 | in=34,758 | out=64 | cached=98.7% | cache_new=198 | $0.0191`
#
# </details>

# %% [markdown]
# Custom markdown renderer that extends `FrankenRenderer`. Automatically adds `target="_blank"` and `rel="noopener noreferrer"` to external links (http/https).

# %% [markdown]
# ### Export

# %%
nbdev.nbdev_export()

# %% [markdown]
# Exports all cells marked with `#| export` to the `my_blog/core_v5.py` module file.
